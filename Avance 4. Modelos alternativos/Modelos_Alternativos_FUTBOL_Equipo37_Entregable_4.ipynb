# %%
AVAILABLE_SEASSONS = [
    '2021', '2022', '2023',
    '2024', '2025', '2026'
]

TAG_TEAM = 42
TAG_TEAM_NAME = "ARSENAL"

# %%
# Selecciones nacionales
TAG_LEAGUES = [1, 4, 5, 9, 10, 21, 22, 31, 32, 37, 536, 960]

# Premier league (Inglaterra)
TAG_LEAGUES = [39]

# %% [markdown]
# ### Librerias

# %%
from google.colab import userdata

import pandas as pd
import json

# Numeric
import numpy as np
import math

# API
import time
from tqdm.notebook import tqdm
import requests
import http.client

# Visualizations
import seaborn as sns
import matplotlib.pyplot as plt

# ML
from scipy.stats import poisson
from sklearn.linear_model import PoissonRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import warnings

#Alternative models
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import f1_score

# %% [markdown]
# ## **Pasos iniciales**
#
# * Funciones para hacer llamadas a la API de datos (API-FOOTBALL)

# %% [markdown]
# ### Función para hacer llamadas a la API

# %%
def get_dataframe_api(endpoint:str):

  url = f"https://v3.football.api-sports.io/{endpoint}"
  headers = {
    "x-apisports-key": userdata.get("api-football-key")
  }

  r = requests.get(url=url,
                   headers=headers)

  print(f"No. errors: ", len(r.json()['errors']))
  print(f"No. results: ", r.json()['results'])
  print(f"----\n\n\n")

  return r.json()['response'], r.json()['results']

# %% [markdown]
# ### Función para obtener el ID de los torenos del equipo seleccionado

# %%
def get_tag_leagues_from_especify_team():
  leagues = set()

  for sesson in AVAILABLE_SEASSONS:

    endpoint_fixtures = f"fixtures?team={TAG_TEAM}&season={sesson}"

    data_fixtures, num_api_results = get_dataframe_api(endpoint_fixtures)

    data_fixtures

    for match in data_fixtures:
        leagues.add(match["league"]["id"])

    print(f"--> Sesson: {sesson} - {leagues} <--\n\n")

  tag_leagues = np.array(sorted(leagues))

  return tag_leagues

# %%
TAG_LEAGUES = get_tag_leagues_from_especify_team()
# Out:
# No. errors:  0
# No. results:  52
# ----
#
#
#
# --> Sesson: 2021 - {48, 667, 45, 39} <--
#
#
# No. errors:  0
# No. results:  57
# ----
#
#
#
# --> Sesson: 2022 - {3, 39, 937, 45, 48, 667} <--
#
#
# No. errors:  0
# No. results:  57
# ----
#
#
#
# --> Sesson: 2023 - {866, 3, 2, 39, 937, 45, 48, 528, 667} <--
#
#
# No. errors:  0
# No. results:  63
# ----
#
#
#
# --> Sesson: 2024 - {866, 3, 2, 39, 937, 45, 48, 528, 667} <--
#
#
# No. errors:  0
# No. results:  69
# ----
#
#
#
# --> Sesson: 2025 - {866, 3, 2, 39, 937, 45, 48, 528, 667} <--
#
#
# No. errors:  0
# No. results:  1
# ----
#
#
#
# --> Sesson: 2026 - {866, 3, 2, 39, 937, 45, 48, 528, 667} <--

# %% [markdown]
# ### <font color=purple>Obtener un dataframe de un equipo específcio</font>
#  * Obtiene todos los partidos de todas las ligas en las que juega el equipo

# %%
def get_clean_fixtures(data, target_id=42):
  processed_matches = []

  for m in data:
    is_home = m['teams']['home']['id'] == target_id

    status_match = m['fixture']['status']['short']


    if status_match != 'FT':
      continue

    team_side = 'home' if is_home else 'away'
    rival_side = 'away' if is_home else 'home'

    match_info = {
            'fixture_id': m['fixture']['id'],
            'season': m['league']['season'],
            'date': m['fixture']['date'],
            'team_name': m['teams'][team_side]['name'],
            'opponent_name': m['teams'][rival_side]['name'],
            'match_result': m['teams'][team_side]['winner'],
            'goals_for': m['goals'][team_side],
            'goals_against': m['goals'][rival_side],
            'is_home': is_home
    }

    processed_matches.append(match_info)

  return pd.DataFrame(processed_matches)

# %%
def get_general_results_matches():

  df_fixtures_all_sessons = []

  for sesson in AVAILABLE_SEASSONS:
    print(f"SEASON: {sesson}")

    for id_league in TAG_LEAGUES:
      print(f"ID LEAGUE: {id_league}")

      endpoint_fixtures = f"fixtures?league={id_league}&season={sesson}&team={TAG_TEAM}"

      data_fixtures, num_api_results = get_dataframe_api(endpoint_fixtures)

      if num_api_results < 1:
        continue

      df_fixtures_per_sesson = get_clean_fixtures(data_fixtures,
                                                  target_id=TAG_TEAM)

      df_fixtures_all_sessons.append(df_fixtures_per_sesson)

  df_fixtures_all_sessons = pd.concat(df_fixtures_all_sessons,
                                      ignore_index=True)

  return df_fixtures_all_sessons

# %% [markdown]
# ### <font color="green">Obtener un dataframe de un todos los equipos</font>
#  * Obtiene todos los partidos de todas las ligas especificadas en TAG_LEAGUES

# %%
def get_clean_fixtures_all_teams(data):
  processed_matches = []

  for m in data:
    status_match = m['fixture']['status']['short']


    if status_match != 'FT':
      continue


    match_info = {
            'fixture_id': m['fixture']['id'],
            'season': m['league']['season'],
            'date': m['fixture']['date'],
            'home_team': m['teams']['home']['name'],
            'away_team': m['teams']['away']['name'],
            'home_goals': m['goals']['home'],
            'away_goals': m['goals']['away']
    }

    processed_matches.append(match_info)

  return pd.DataFrame(processed_matches)

# %%
def get_general_results_matches_all_teams():

  df_fixtures_all_sessons = []

  for sesson in AVAILABLE_SEASSONS:
    print(f"SEASON: {sesson}")

    for id_league in TAG_LEAGUES:
      print(f"ID LEAGUE: {id_league}")

      endpoint_fixtures = f"fixtures?league={id_league}&season={sesson}"

      data_fixtures, num_api_results = get_dataframe_api(endpoint_fixtures)

      if num_api_results < 1:
        continue

      df_fixtures_per_sesson = get_clean_fixtures_all_teams(data_fixtures)

      df_fixtures_all_sessons.append(df_fixtures_per_sesson)

  df_fixtures_all_sessons = pd.concat(df_fixtures_all_sessons,
                                      ignore_index=True)

  return df_fixtures_all_sessons

# %% [markdown]
# ## 📊 <font color=#258FE8>**EDA**</font> (Avance 1)

# %% [markdown]
# ### Mostrar el data DF con estadísticas generales de los partidos
#
# * Oponente
# * Resultado
# * Goles a favor
# * Goles encontra
# * ¿Es visitante?

# %%
df_fixtures_all_sessons = get_general_results_matches()
# Out:
# SEASON: 2021
# ID LEAGUE: 2
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  38
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  6
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  7
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  0
# ----
#
#
#
# SEASON: 2022
# ID LEAGUE: 2
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  8
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  38
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  2
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  7
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  1
# ----
#
#
#
# SEASON: 2023
# ID LEAGUE: 2
# No. errors:  0
# No. results:  10
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  38
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  2
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  3
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  1
# ----
#
#
#
# SEASON: 2024
# ID LEAGUE: 2
# No. errors:  0
# No. results:  14
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  38
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  5
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  4
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  1
# ----
#
#
#
# SEASON: 2025
# ID LEAGUE: 2
# No. errors:  0
# No. results:  15
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  38
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  4
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  6
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  5
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  1
# ----
#
#
#
# SEASON: 2026
# ID LEAGUE: 2
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  0
# ----

# %%
df_fixtures_all_sessons.shape
# Out:
# (284, 9)

# %%
df_fixtures_all_sessons.head()
# Out:
#    fixture_id  season                       date team_name    opponent_name  \
# 0      710556    2021  2021-08-13T19:00:00+00:00   Arsenal        Brentford
# 1      710566    2021  2021-08-22T15:30:00+00:00   Arsenal          Chelsea
# 2      710580    2021  2021-08-28T11:30:00+00:00   Arsenal  Manchester City
# 3      710586    2021  2021-09-11T14:00:00+00:00   Arsenal          Norwich
# 4      710598    2021  2021-09-18T14:00:00+00:00   Arsenal          Burnley
#
#   match_result  goals_for  goals_against  is_home
# 0        False          0              2    False
# 1        False          0              2     True
# 2        False          0              5    False
# 3         True          1              0     True
# 4         True          1              0    False

# %% [markdown]
# Nota: Convertimos la columna 'date' a tipo de dato de fecha

# %%
df_fixtures_all_sessons['date'] = pd.to_datetime(df_fixtures_all_sessons['date'])
df_fixtures_all_sessons = df_fixtures_all_sessons.sort_values(by='date')
df_fixtures_all_sessons.head(2)
# Out:
#     fixture_id  season                      date team_name opponent_name  \
# 46      736003    2021 2021-07-13 17:00:00+00:00   Arsenal     Hibernian
# 45      735990    2021 2021-07-17 13:00:00+00:00   Arsenal       Rangers
#
#    match_result  goals_for  goals_against  is_home
# 46        False          1              2    False
# 45         None          2              2    False

# %% [markdown]
# ### Obtener estadísticas profundas de los partidos

# %%
df_fixtures_all_sessons_stats = []
df_no_match_information = []

for index, fixture in df_fixtures_all_sessons.iterrows():

  # Plan Pro: 300 requests per minute
  if index > 0 and (index % 300 == 0):
    for i in tqdm(range(65)):
      time.sleep(1)


  endpoint_fixtures_stats = f"fixtures/statistics?fixture={fixture['fixture_id']}&half=false"

  print(f"Index No: {index}")
  print(f"ID partido: {fixture['fixture_id']}")
  print(f"Enpoint: {endpoint_fixtures_stats}")

  data, _ = get_dataframe_api(endpoint_fixtures_stats)

  print(data)

  if not data:
    print("No match information")
    df_no_match_information.append(fixture['fixture_id'])
    continue

  team_target = next(item for item in data if item["team"]["id"] == TAG_TEAM)
  team_rival = next(item for item in data if item["team"]["id"] != TAG_TEAM)

  stats_target = {item['type']: item['value'] for item in team_target['statistics']}
  stats_rival = {item['type']: item['value'] for item in team_rival['statistics']}

  df = pd.DataFrame([{
    'team_id': team_target['team']['id'],
    'team_name': team_target['team']['name'],
    'total_shots': stats_target.get("Total Shots"),
    'shots_on_goal': stats_target.get("Shots on Goal"),
    'fouls': stats_target.get("Fouls"),
    'corner_kicks': stats_target.get("Corner Kicks"),
    'offsides': stats_target.get("Offsides"),
    'ball_possession': stats_target.get("Ball Possession"),
    'yellow_cards': stats_target.get("Yellow Cards"),
    'goalkeeper_saves': stats_target.get("Goalkeeper Saves"),
    'passes_percentage': stats_target.get("Passes %"),
    'total_passes': stats_target.get("Total passes"),
    'passes_accurate': stats_target.get("Passes accurate"),
    'shots_received': stats_rival.get("Total Shots"),
    'shots_on_goal_received': stats_rival.get("Shots on Goal"),
    'fixture_id': fixture['fixture_id'],
    'match_result': fixture['match_result'],
    'goals_for': fixture['goals_for'],
    'goals_against': fixture['goals_against'],
    'is_home': fixture['is_home'],
    'season': fixture['season']
  }])

  df_fixtures_all_sessons_stats.append(df)

print(f"{len(df_fixtures_all_sessons)}/{len(df_no_match_information)}")

df_fixtures_all_sessons_stats = pd.concat(df_fixtures_all_sessons_stats,
                                          ignore_index=True)
# Out:
# Index No: 46
# ID partido: 736003
# Enpoint: fixtures/statistics?fixture=736003&half=false
# No. errors:  0
# No. results:  0
# ----
#
#
#
# []
# No match information
# Index No: 45
# ID partido: 735990
# Enpoint: fixtures/statistics?fixture=735990&half=false
# No. errors:  0
# No. results:  0
# ----
#
#
#
# []
# No match information
# Index No: 49
# ID partido: 745381
# Enpoint: fixtures/statistics?fixture=745381&half=false
# No. errors:  0
# No. results:  0
# ----
#
#
#
# []
# No match information
# Index No: 50
# ID partido: 748877
# Enpoint: fixtures/statistics?fixture=748877&half=false
# No. errors:  0
# No. results:  0
# ----
#
#
#
# []
# No match information
# Index No: 47
# ID partido: 736041
# Enpoint: fixtures/statistics?fixture=736041&half=false
# No. errors:  0
# No. results:  0
# ----
#
#
#
# []
# No match information
# Index No: 48
# ID partido: 736045
# Enpoint: fixtures/statistics?fixture=736045&half=false
# No. errors:  0
# No. results:  0
# ----
#
#
#
# []
# No match information
# Index No: 0
# ID partido: 710556
# Enpoint: fixtures/statistics?fixture=710556&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 55, 'name': 'Brentford', 'logo': 'https://media.api-sports.io/football/teams/55.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 8}, {'type': 'Blocked Shots', 'value': 0}, {'type': 'Shots insidebox', 'value': 7}, {'type': 'Shots outsidebox', 'value': 1}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 2}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '35%'}, {'type': 'Yellow Cards', 'value': None}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 4}, {'type': 'Total passes', 'value': 309}, {'type': 'Passes accurate', 'value': 201}, {'type': 'Passes %', 'value': '65%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 4}, {'type': 'Shots off Goal', 'value': 14}, {'type': 'Total Shots', 'value': 22}, {'type': 'Blocked Shots', 'value': 4}, {'type': 'Shots insidebox', 'value': 13}, {'type': 'Shots outsidebox', 'value': 9}, {'type': 'Fouls', 'value': 8}, {'type': 'Corner Kicks', 'value': 5}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '65%'}, {'type': 'Yellow Cards', 'value': None}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 568}, {'type': 'Passes accurate', 'value': 488}, {'type': 'Passes %', 'value': '86%'}]}]
# Index No: 1
# ID partido: 710566
# Enpoint: fixtures/statistics?fixture=710566&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 2}, {'type': 'Total Shots', 'value': 6}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 3}, {'type': 'Shots outsidebox', 'value': 3}, {'type': 'Fouls', 'value': 10}, {'type': 'Corner Kicks', 'value': 9}, {'type': 'Offsides', 'value': 5}, {'type': 'Ball Possession', 'value': '35%'}, {'type': 'Yellow Cards', 'value': 3}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 335}, {'type': 'Passes accurate', 'value': 266}, {'type': 'Passes %', 'value': '79%'}]}, {'team': {'id': 49, 'name': 'Chelsea', 'logo': 'https://media.api-sports.io/football/teams/49.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 5}, {'type': 'Shots off Goal', 'value': 6}, {'type': 'Total Shots', 'value': 22}, {'type': 'Blocked Shots', 'value': 11}, {'type': 'Shots insidebox', 'value': 15}, {'type': 'Shots outsidebox', 'value': 7}, {'type': 'Fouls', 'value': 4}, {'type': 'Corner Kicks', 'value': 8}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '65%'}, {'type': 'Yellow Cards', 'value': 0}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 646}, {'type': 'Passes accurate', 'value': 574}, {'type': 'Passes %', 'value': '89%'}]}]
# Index No: 39
# ID partido: 766563
# Enpoint: fixtures/statistics?fixture=766563&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 60, 'name': 'West Brom', 'logo': 'https://media.api-sports.io/football/teams/60.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 4}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 11}, {'type': 'Blocked Shots', 'value': 4}, {'type': 'Shots insidebox', 'value': 8}, {'type': 'Shots outsidebox', 'value': 3}, {'type': 'Fouls', 'value': 4}, {'type': 'Corner Kicks', 'value': 5}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '26%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 214}, {'type': 'Passes accurate', 'value': 131}, {'type': 'Passes %', 'value': '61%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 9}, {'type': 'Shots off Goal', 'value': 4}, {'type': 'Total Shots', 'value': 14}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 13}, {'type': 'Shots outsidebox', 'value': 1}, {'type': 'Fouls', 'value': 5}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '74%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 4}, {'type': 'Total passes', 'value': 640}, {'type': 'Passes accurate', 'value': 566}, {'type': 'Passes %', 'value': '88%'}]}]
# Index No: 2
# ID partido: 710580
# Enpoint: fixtures/statistics?fixture=710580&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 50, 'name': 'Manchester City', 'logo': 'https://media.api-sports.io/football/teams/50.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 10}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 25}, {'type': 'Blocked Shots', 'value': 10}, {'type': 'Shots insidebox', 'value': 17}, {'type': 'Shots outsidebox', 'value': 8}, {'type': 'Fouls', 'value': 5}, {'type': 'Corner Kicks', 'value': 14}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '80%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': 0}, {'type': 'Goalkeeper Saves', 'value': 0}, {'type': 'Total passes', 'value': 757}, {'type': 'Passes accurate', 'value': 693}, {'type': 'Passes %', 'value': '92%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 0}, {'type': 'Shots off Goal', 'value': 1}, {'type': 'Total Shots', 'value': 1}, {'type': 'Blocked Shots', 'value': 0}, {'type': 'Shots insidebox', 'value': 1}, {'type': 'Shots outsidebox', 'value': 0}, {'type': 'Fouls', 'value': 7}, {'type': 'Corner Kicks', 'value': 0}, {'type': 'Offsides', 'value': 3}, {'type': 'Ball Possession', 'value': '20%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': 1}, {'type': 'Goalkeeper Saves', 'value': 5}, {'type': 'Total passes', 'value': 185}, {'type': 'Passes accurate', 'value': 125}, {'type': 'Passes %', 'value': '68%'}]}]
# Index No: 3
# ID partido: 710586
# Enpoint: fixtures/statistics?fixture=710586&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 7}, {'type': 'Shots off Goal', 'value': 13}, {'type': 'Total Shots', 'value': 30}, {'type': 'Blocked Shots', 'value': 10}, {'type': 'Shots insidebox', 'value': 21}, {'type': 'Shots outsidebox', 'value': 9}, {'type': 'Fouls', 'value': 9}, {'type': 'Corner Kicks', 'value': 8}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '52%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 437}, {'type': 'Passes accurate', 'value': 365}, {'type': 'Passes %', 'value': '84%'}]}, {'team': {'id': 71, 'name': 'Norwich', 'logo': 'https://media.api-sports.io/football/teams/71.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 1}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 10}, {'type': 'Blocked Shots', 'value': 6}, {'type': 'Shots insidebox', 'value': 5}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 11}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '48%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 5}, {'type': 'Total passes', 'value': 408}, {'type': 'Passes accurate', 'value': 320}, {'type': 'Passes %', 'value': '78%'}]}]
# Index No: 4
# ID partido: 710598
# Enpoint: fixtures/statistics?fixture=710598&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 44, 'name': 'Burnley', 'logo': 'https://media.api-sports.io/football/teams/44.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 10}, {'type': 'Total Shots', 'value': 18}, {'type': 'Blocked Shots', 'value': 5}, {'type': 'Shots insidebox', 'value': 13}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 9}, {'type': 'Corner Kicks', 'value': 8}, {'type': 'Offsides', 'value': 4}, {'type': 'Ball Possession', 'value': '45%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 392}, {'type': 'Passes accurate', 'value': 291}, {'type': 'Passes %', 'value': '74%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 4}, {'type': 'Total Shots', 'value': 13}, {'type': 'Blocked Shots', 'value': 6}, {'type': 'Shots insidebox', 'value': 6}, {'type': 'Shots outsidebox', 'value': 7}, {'type': 'Fouls', 'value': 8}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '55%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 523}, {'type': 'Passes accurate', 'value': 420}, {'type': 'Passes %', 'value': '80%'}]}]
# Index No: 40
# ID partido: 787058
# Enpoint: fixtures/statistics?fixture=787058&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 5}, {'type': 'Shots off Goal', 'value': 8}, {'type': 'Total Shots', 'value': 19}, {'type': 'Blocked Shots', 'value': 6}, {'type': 'Shots insidebox', 'value': 12}, {'type': 'Shots outsidebox', 'value': 7}, {'type': 'Fouls', 'value': 8}, {'type': 'Corner Kicks', 'value': 10}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '62%'}, {'type': 'Yellow Cards', 'value': 0}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 0}, {'type': 'Total passes', 'value': 563}, {'type': 'Passes accurate', 'value': 497}, {'type': 'Passes %', 'value': '88%'}]}, {'team': {'id': 1333, 'name': 'AFC Wimbledon', 'logo': 'https://media.api-sports.io/football/teams/1333.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 0}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 4}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 3}, {'type': 'Shots outsidebox', 'value': 1}, {'type': 'Fouls', 'value': 10}, {'type': 'Corner Kicks', 'value': 2}, {'type': 'Offsides', 'value': 5}, {'type': 'Ball Possession', 'value': '38%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 341}, {'type': 'Passes accurate', 'value': 278}, {'type': 'Passes %', 'value': '82%'}]}]
# Index No: 5
# ID partido: 710606
# Enpoint: fixtures/statistics?fixture=710606&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 7}, {'type': 'Shots off Goal', 'value': 4}, {'type': 'Total Shots', 'value': 12}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 7}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '47%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 431}, {'type': 'Passes accurate', 'value': 357}, {'type': 'Passes %', 'value': '83%'}]}, {'team': {'id': 47, 'name': 'Tottenham', 'logo': 'https://media.api-sports.io/football/teams/47.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 4}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 10}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 7}, {'type': 'Shots outsidebox', 'value': 3}, {'type': 'Fouls', 'value': 13}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 4}, {'type': 'Ball Possession', 'value': '53%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 4}, {'type': 'Total passes', 'value': 485}, {'type': 'Passes accurate', 'value': 413}, {'type': 'Passes %', 'value': '85%'}]}]
# Index No: 6
# ID partido: 710616
# Enpoint: fixtures/statistics?fixture=710616&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 51, 'name': 'Brighton', 'logo': 'https://media.api-sports.io/football/teams/51.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 2}, {'type': 'Shots off Goal', 'value': 12}, {'type': 'Total Shots', 'value': 21}, {'type': 'Blocked Shots', 'value': 7}, {'type': 'Shots insidebox', 'value': 13}, {'type': 'Shots outsidebox', 'value': 8}, {'type': 'Fouls', 'value': 8}, {'type': 'Corner Kicks', 'value': 8}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '58%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 497}, {'type': 'Passes accurate', 'value': 420}, {'type': 'Passes %', 'value': '85%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 2}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 8}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 4}, {'type': 'Shots outsidebox', 'value': 4}, {'type': 'Fouls', 'value': 5}, {'type': 'Corner Kicks', 'value': 5}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '42%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 355}, {'type': 'Passes accurate', 'value': 268}, {'type': 'Passes %', 'value': '75%'}]}]
# Index No: 7
# ID partido: 710626
# Enpoint: fixtures/statistics?fixture=710626&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 6}, {'type': 'Shots off Goal', 'value': 7}, {'type': 'Total Shots', 'value': 17}, {'type': 'Blocked Shots', 'value': 4}, {'type': 'Shots insidebox', 'value': 11}, {'type': 'Shots outsidebox', 'value': 6}, {'type': 'Fouls', 'value': 7}, {'type': 'Corner Kicks', 'value': 6}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '54%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 4}, {'type': 'Total passes', 'value': 544}, {'type': 'Passes accurate', 'value': 474}, {'type': 'Passes %', 'value': '87%'}]}, {'team': {'id': 52, 'name': 'Crystal Palace', 'logo': 'https://media.api-sports.io/football/teams/52.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 6}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 9}, {'type': 'Blocked Shots', 'value': 0}, {'type': 'Shots insidebox', 'value': 3}, {'type': 'Shots outsidebox', 'value': 6}, {'type': 'Fouls', 'value': 4}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': 3}, {'type': 'Ball Possession', 'value': '46%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 4}, {'type': 'Total passes', 'value': 475}, {'type': 'Passes accurate', 'value': 402}, {'type': 'Passes %', 'value': '85%'}]}]
# Index No: 8
# ID partido: 710636
# Enpoint: fixtures/statistics?fixture=710636&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 9}, {'type': 'Shots off Goal', 'value': 8}, {'type': 'Total Shots', 'value': 22}, {'type': 'Blocked Shots', 'value': 5}, {'type': 'Shots insidebox', 'value': 14}, {'type': 'Shots outsidebox', 'value': 8}, {'type': 'Fouls', 'value': 17}, {'type': 'Corner Kicks', 'value': 7}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '54%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 454}, {'type': 'Passes accurate', 'value': 369}, {'type': 'Passes %', 'value': '81%'}]}, {'team': {'id': 66, 'name': 'Aston Villa', 'logo': 'https://media.api-sports.io/football/teams/66.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 4}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 10}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 5}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 10}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '46%'}, {'type': 'Yellow Cards', 'value': 5}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 6}, {'type': 'Total passes', 'value': 392}, {'type': 'Passes accurate', 'value': 310}, {'type': 'Passes %', 'value': '79%'}]}]
# Index No: 41
# ID partido: 800353
# Enpoint: fixtures/statistics?fixture=800353&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 4}, {'type': 'Shots off Goal', 'value': 6}, {'type': 'Total Shots', 'value': 14}, {'type': 'Blocked Shots', 'value': 4}, {'type': 'Shots insidebox', 'value': 13}, {'type': 'Shots outsidebox', 'value': 1}, {'type': 'Fouls', 'value': 5}, {'type': 'Corner Kicks', 'value': 10}, {'type': 'Offsides', 'value': 3}, {'type': 'Ball Possession', 'value': '45%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 5}, {'type': 'Total passes', 'value': 347}, {'type': 'Passes accurate', 'value': 279}, {'type': 'Passes %', 'value': '80%'}]}, {'team': {'id': 63, 'name': 'Leeds', 'logo': 'https://media.api-sports.io/football/teams/63.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 5}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 14}, {'type': 'Blocked Shots', 'value': 6}, {'type': 'Shots insidebox', 'value': 9}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '55%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 452}, {'type': 'Passes accurate', 'value': 372}, {'type': 'Passes %', 'value': '82%'}]}]
# Index No: 9
# ID partido: 710648
# Enpoint: fixtures/statistics?fixture=710648&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 46, 'name': 'Leicester', 'logo': 'https://media.api-sports.io/football/teams/46.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 8}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 16}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 8}, {'type': 'Shots outsidebox', 'value': 8}, {'type': 'Fouls', 'value': 8}, {'type': 'Corner Kicks', 'value': 7}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '64%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 4}, {'type': 'Total passes', 'value': 621}, {'type': 'Passes accurate', 'value': 541}, {'type': 'Passes %', 'value': '87%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 5}, {'type': 'Shots off Goal', 'value': 1}, {'type': 'Total Shots', 'value': 9}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 7}, {'type': 'Shots outsidebox', 'value': 2}, {'type': 'Fouls', 'value': 11}, {'type': 'Corner Kicks', 'value': 6}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '36%'}, {'type': 'Yellow Cards', 'value': 0}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 8}, {'type': 'Total passes', 'value': 342}, {'type': 'Passes accurate', 'value': 262}, {'type': 'Passes %', 'value': '77%'}]}]
# Index No: 10
# ID partido: 710656
# Enpoint: fixtures/statistics?fixture=710656&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 6}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 14}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 6}, {'type': 'Shots outsidebox', 'value': 8}, {'type': 'Fouls', 'value': 6}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 3}, {'type': 'Ball Possession', 'value': '61%'}, {'type': 'Yellow Cards', 'value': 4}, {'type': 'Red Cards', 'value': 0}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 488}, {'type': 'Passes accurate', 'value': 409}, {'type': 'Passes %', 'value': '84%'}]}, {'team': {'id': 38, 'name': 'Watford', 'logo': 'https://media.api-sports.io/football/teams/38.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 1}, {'type': 'Shots off Goal', 'value': 2}, {'type': 'Total Shots', 'value': 7}, {'type': 'Blocked Shots', 'value': 4}, {'type': 'Shots insidebox', 'value': 4}, {'type': 'Shots outsidebox', 'value': 3}, {'type': 'Fouls', 'value': 19}, {'type': 'Corner Kicks', 'value': 2}, {'type': 'Offsides', 'value': 3}, {'type': 'Ball Possession', 'value': '39%'}, {'type': 'Yellow Cards', 'value': 4}, {'type': 'Red Cards', 'value': 1}, {'type': 'Goalkeeper Saves', 'value': 5}, {'type': 'Total passes', 'value': 316}, {'type': 'Passes accurate', 'value': 228}, {'type': 'Passes %', 'value': '72%'}]}]
# Index No: 11
# ID partido: 710669
# Enpoint: fixtures/statistics?fixture=710669&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 40, 'name': 'Liverpool', 'logo': 'https://media.api-sports.io/football/teams/40.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 9}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 19}, {'type': 'Blocked Shots', 'value': 7}, {'type': 'Shots insidebox', 'value': 16}, {'type': 'Shots outsidebox', 'value': 3}, {'type': 'Fouls', 'value': 15}, {'type': 'Corner Kicks', 'value': 6}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '63%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 639}, {'type': 'Passes accurate', 'value': 565}, {'type': 'Passes %', 'value': '88%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 0}, {'type': 'Total Shots', 'value': 5}, {'type': 'Blocked Shots', 'value': 2}, {'type': 'Shots insidebox', 'value': 3}, {'type': 'Shots outsidebox', 'value': 2}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 1}, {'type': 'Offsides', 'value': 8}, {'type': 'Ball Possession', 'value': '37%'}, {'type': 'Yellow Cards', 'value': 0}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 5}, {'type': 'Total passes', 'value': 384}, {'type': 'Passes accurate', 'value': 311}, {'type': 'Passes %', 'value': '81%'}]}]
# Index No: 12
# ID partido: 710676
# Enpoint: fixtures/statistics?fixture=710676&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 6}, {'type': 'Shots off Goal', 'value': 12}, {'type': 'Total Shots', 'value': 24}, {'type': 'Blocked Shots', 'value': 6}, {'type': 'Shots insidebox', 'value': 14}, {'type': 'Shots outsidebox', 'value': 10}, {'type': 'Fouls', 'value': 6}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '66%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 5}, {'type': 'Total passes', 'value': 646}, {'type': 'Passes accurate', 'value': 563}, {'type': 'Passes %', 'value': '87%'}]}, {'team': {'id': 34, 'name': 'Newcastle', 'logo': 'https://media.api-sports.io/football/teams/34.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 5}, {'type': 'Shots off Goal', 'value': 2}, {'type': 'Total Shots', 'value': 9}, {'type': 'Blocked Shots', 'value': 2}, {'type': 'Shots insidebox', 'value': 3}, {'type': 'Shots outsidebox', 'value': 6}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 3}, {'type': 'Ball Possession', 'value': '34%'}, {'type': 'Yellow Cards', 'value': 3}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 4}, {'type': 'Total passes', 'value': 328}, {'type': 'Passes accurate', 'value': 262}, {'type': 'Passes %', 'value': '80%'}]}]
# Index No: 13
# ID partido: 710692
# Enpoint: fixtures/statistics?fixture=710692&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media.api-sports.io/football/teams/33.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 10}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 14}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 9}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 9}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '45%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 5}, {'type': 'Total passes', 'value': 431}, {'type': 'Passes accurate', 'value': 354}, {'type': 'Passes %', 'value': '82%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 8}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 17}, {'type': 'Blocked Shots', 'value': 4}, {'type': 'Shots insidebox', 'value': 12}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 10}, {'type': 'Corner Kicks', 'value': 8}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '55%'}, {'type': 'Yellow Cards', 'value': 0}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 7}, {'type': 'Total passes', 'value': 526}, {'type': 'Passes accurate', 'value': 440}, {'type': 'Passes %', 'value': '84%'}]}]
# Index No: 14
# ID partido: 710697
# Enpoint: fixtures/statistics?fixture=710697&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 45, 'name': 'Everton', 'logo': 'https://media.api-sports.io/football/teams/45.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 5}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 11}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 7}, {'type': 'Shots outsidebox', 'value': 4}, {'type': 'Fouls', 'value': 8}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': 5}, {'type': 'Ball Possession', 'value': '36%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 329}, {'type': 'Passes accurate', 'value': 228}, {'type': 'Passes %', 'value': '69%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 4}, {'type': 'Total Shots', 'value': 10}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 8}, {'type': 'Shots outsidebox', 'value': 2}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '64%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 588}, {'type': 'Passes accurate', 'value': 486}, {'type': 'Passes %', 'value': '83%'}]}]
# Index No: 15
# ID partido: 710706
# Enpoint: fixtures/statistics?fixture=710706&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 5}, {'type': 'Shots off Goal', 'value': 7}, {'type': 'Total Shots', 'value': 15}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 11}, {'type': 'Shots outsidebox', 'value': 4}, {'type': 'Fouls', 'value': 5}, {'type': 'Corner Kicks', 'value': 9}, {'type': 'Offsides', 'value': 3}, {'type': 'Ball Possession', 'value': '61%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 6}, {'type': 'Total passes', 'value': 507}, {'type': 'Passes accurate', 'value': 405}, {'type': 'Passes %', 'value': '80%'}]}, {'team': {'id': 41, 'name': 'Southampton', 'logo': 'https://media.api-sports.io/football/teams/41.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 6}, {'type': 'Shots off Goal', 'value': 2}, {'type': 'Total Shots', 'value': 11}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 4}, {'type': 'Shots outsidebox', 'value': 7}, {'type': 'Fouls', 'value': 9}, {'type': 'Corner Kicks', 'value': 8}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '39%'}, {'type': 'Yellow Cards', 'value': 0}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 320}, {'type': 'Passes accurate', 'value': 237}, {'type': 'Passes %', 'value': '74%'}]}]
# Index No: 16
# ID partido: 710716
# Enpoint: fixtures/statistics?fixture=710716&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 8}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 21}, {'type': 'Blocked Shots', 'value': 8}, {'type': 'Shots insidebox', 'value': 11}, {'type': 'Shots outsidebox', 'value': 10}, {'type': 'Fouls', 'value': 9}, {'type': 'Corner Kicks', 'value': 5}, {'type': 'Offsides', 'value': None}, {'type': 'Ball Possession', 'value': '56%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': 0}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 501}, {'type': 'Passes accurate', 'value': 420}, {'type': 'Passes %', 'value': '84%'}]}, {'team': {'id': 48, 'name': 'West Ham', 'logo': 'https://media.api-sports.io/football/teams/48.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 1}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 7}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 2}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 9}, {'type': 'Corner Kicks', 'value': 2}, {'type': 'Offsides', 'value': None}, {'type': 'Ball Possession', 'value': '44%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': 1}, {'type': 'Goalkeeper Saves', 'value': 6}, {'type': 'Total passes', 'value': 387}, {'type': 'Passes accurate', 'value': 314}, {'type': 'Passes %', 'value': '81%'}]}]
# Index No: 17
# ID partido: 710728
# Enpoint: fixtures/statistics?fixture=710728&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 63, 'name': 'Leeds', 'logo': 'https://media.api-sports.io/football/teams/63.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 2}, {'type': 'Shots off Goal', 'value': 6}, {'type': 'Total Shots', 'value': 9}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 4}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 11}, {'type': 'Corner Kicks', 'value': 1}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '51%'}, {'type': 'Yellow Cards', 'value': 3}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 8}, {'type': 'Total passes', 'value': 405}, {'type': 'Passes accurate', 'value': 312}, {'type': 'Passes %', 'value': '77%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 12}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 21}, {'type': 'Blocked Shots', 'value': 6}, {'type': 'Shots insidebox', 'value': 14}, {'type': 'Shots outsidebox', 'value': 7}, {'type': 'Fouls', 'value': 7}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '49%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 392}, {'type': 'Passes accurate', 'value': 305}, {'type': 'Passes %', 'value': '78%'}]}]
# Index No: 42
# ID partido: 810061
# Enpoint: fixtures/statistics?fixture=810061&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 10}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 19}, {'type': 'Blocked Shots', 'value': 4}, {'type': 'Shots insidebox', 'value': 16}, {'type': 'Shots outsidebox', 'value': 3}, {'type': 'Fouls', 'value': 10}, {'type': 'Corner Kicks', 'value': 2}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '68%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 5}, {'type': 'Total passes', 'value': 619}, {'type': 'Passes accurate', 'value': 562}, {'type': 'Passes %', 'value': '91%'}]}, {'team': {'id': 746, 'name': 'Sunderland', 'logo': 'https://media.api-sports.io/football/teams/746.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 6}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 12}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 6}, {'type': 'Shots outsidebox', 'value': 6}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 5}, {'type': 'Offsides', 'value': 5}, {'type': 'Ball Possession', 'value': '32%'}, {'type': 'Yellow Cards', 'value': 4}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 4}, {'type': 'Total passes', 'value': 278}, {'type': 'Passes accurate', 'value': 220}, {'type': 'Passes %', 'value': '79%'}]}]
# Index No: 18
# ID partido: 710742
# Enpoint: fixtures/statistics?fixture=710742&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 71, 'name': 'Norwich', 'logo': 'https://media.api-sports.io/football/teams/71.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 2}, {'type': 'Shots off Goal', 'value': 1}, {'type': 'Total Shots', 'value': 4}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 3}, {'type': 'Shots outsidebox', 'value': 1}, {'type': 'Fouls', 'value': 13}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': 3}, {'type': 'Ball Possession', 'value': '35%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 314}, {'type': 'Passes accurate', 'value': 228}, {'type': 'Passes %', 'value': '73%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 6}, {'type': 'Shots off Goal', 'value': 4}, {'type': 'Total Shots', 'value': 16}, {'type': 'Blocked Shots', 'value': 6}, {'type': 'Shots insidebox', 'value': 11}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 7}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '65%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 585}, {'type': 'Passes accurate', 'value': 493}, {'type': 'Passes %', 'value': '84%'}]}]
# Index No: 19
# ID partido: 710756
# Enpoint: fixtures/statistics?fixture=710756&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 2}, {'type': 'Shots off Goal', 'value': 4}, {'type': 'Total Shots', 'value': 7}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 5}, {'type': 'Shots outsidebox', 'value': 2}, {'type': 'Fouls', 'value': 13}, {'type': 'Corner Kicks', 'value': 5}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '29%'}, {'type': 'Yellow Cards', 'value': 5}, {'type': 'Red Cards', 'value': 1}, {'type': 'Goalkeeper Saves', 'value': 0}, {'type': 'Total passes', 'value': 249}, {'type': 'Passes accurate', 'value': 179}, {'type': 'Passes %', 'value': '72%'}]}, {'team': {'id': 50, 'name': 'Manchester City', 'logo': 'https://media.api-sports.io/football/teams/50.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 2}, {'type': 'Shots off Goal', 'value': 6}, {'type': 'Total Shots', 'value': 15}, {'type': 'Blocked Shots', 'value': 7}, {'type': 'Shots insidebox', 'value': 8}, {'type': 'Shots outsidebox', 'value': 7}, {'type': 'Fouls', 'value': 5}, {'type': 'Corner Kicks', 'value': 5}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '71%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': 0}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 644}, {'type': 'Passes accurate', 'value': 572}, {'type': 'Passes %', 'value': '89%'}]}]
# Index No: 38
# ID partido: 815169
# Enpoint: fixtures/statistics?fixture=815169&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 65, 'name': 'Nottingham Forest', 'logo': 'https://media.api-sports.io/football/teams/65.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 0}, {'type': 'Total Shots', 'value': 7}, {'type': 'Blocked Shots', 'value': 4}, {'type': 'Shots insidebox', 'value': 3}, {'type': 'Shots outsidebox', 'value': 4}, {'type': 'Fouls', 'value': 16}, {'type': 'Corner Kicks', 'value': 5}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '33%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 0}, {'type': 'Total passes', 'value': 259}, {'type': 'Passes accurate', 'value': 198}, {'type': 'Passes %', 'value': '76%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 0}, {'type': 'Shots off Goal', 'value': 4}, {'type': 'Total Shots', 'value': 10}, {'type': 'Blocked Shots', 'value': 6}, {'type': 'Shots insidebox', 'value': 6}, {'type': 'Shots outsidebox', 'value': 4}, {'type': 'Fouls', 'value': 11}, {'type': 'Corner Kicks', 'value': 6}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '67%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 539}, {'type': 'Passes accurate', 'value': 459}, {'type': 'Passes %', 'value': '85%'}]}]
# Index No: 43
# ID partido: 820051
# Enpoint: fixtures/statistics?fixture=820051&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 40, 'name': 'Liverpool', 'logo': 'https://media.api-sports.io/football/teams/40.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 1}, {'type': 'Shots off Goal', 'value': 10}, {'type': 'Total Shots', 'value': 17}, {'type': 'Blocked Shots', 'value': 6}, {'type': 'Shots insidebox', 'value': 6}, {'type': 'Shots outsidebox', 'value': 11}, {'type': 'Fouls', 'value': 4}, {'type': 'Corner Kicks', 'value': 8}, {'type': 'Offsides', 'value': 4}, {'type': 'Ball Possession', 'value': '78%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': 0}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 682}, {'type': 'Passes accurate', 'value': 583}, {'type': 'Passes %', 'value': '85%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 1}, {'type': 'Shots off Goal', 'value': 1}, {'type': 'Total Shots', 'value': 3}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 2}, {'type': 'Shots outsidebox', 'value': 1}, {'type': 'Fouls', 'value': 7}, {'type': 'Corner Kicks', 'value': 1}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '22%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': 1}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 192}, {'type': 'Passes accurate', 'value': 95}, {'type': 'Passes %', 'value': '49%'}]}]
# Index No: 44
# ID partido: 820050
# Enpoint: fixtures/statistics?fixture=820050&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 2}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 7}, {'type': 'Blocked Shots', 'value': 2}, {'type': 'Shots insidebox', 'value': 5}, {'type': 'Shots outsidebox', 'value': 2}, {'type': 'Fouls', 'value': 13}, {'type': 'Corner Kicks', 'value': 5}, {'type': 'Offsides', 'value': 4}, {'type': 'Ball Possession', 'value': '46%'}, {'type': 'Yellow Cards', 'value': 4}, {'type': 'Red Cards', 'value': 1}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 455}, {'type': 'Passes accurate', 'value': 368}, {'type': 'Passes %', 'value': '81%'}]}, {'team': {'id': 40, 'name': 'Liverpool', 'logo': 'https://media.api-sports.io/football/teams/40.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 11}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 7}, {'type': 'Shots outsidebox', 'value': 4}, {'type': 'Fouls', 'value': 10}, {'type': 'Corner Kicks', 'value': 2}, {'type': 'Offsides', 'value': 3}, {'type': 'Ball Possession', 'value': '54%'}, {'type': 'Yellow Cards', 'value': 3}, {'type': 'Red Cards', 'value': 0}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 524}, {'type': 'Passes accurate', 'value': 425}, {'type': 'Passes %', 'value': '81%'}]}]
# Index No: 20
# ID partido: 710776
# Enpoint: fixtures/statistics?fixture=710776&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 5}, {'type': 'Shots off Goal', 'value': 8}, {'type': 'Total Shots', 'value': 20}, {'type': 'Blocked Shots', 'value': 7}, {'type': 'Shots insidebox', 'value': 13}, {'type': 'Shots outsidebox', 'value': 7}, {'type': 'Fouls', 'value': 9}, {'type': 'Corner Kicks', 'value': 12}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '76%'}, {'type': 'Yellow Cards', 'value': 0}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 643}, {'type': 'Passes accurate', 'value': 564}, {'type': 'Passes %', 'value': '88%'}]}, {'team': {'id': 44, 'name': 'Burnley', 'logo': 'https://media.api-sports.io/football/teams/44.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 1}, {'type': 'Shots off Goal', 'value': 6}, {'type': 'Total Shots', 'value': 10}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 5}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 13}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '24%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 5}, {'type': 'Total passes', 'value': 211}, {'type': 'Passes accurate', 'value': 137}, {'type': 'Passes %', 'value': '65%'}]}]
# Index No: 21
# ID partido: 710791
# Enpoint: fixtures/statistics?fixture=710791&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 39, 'name': 'Wolves', 'logo': 'https://media.api-sports.io/football/teams/39.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 4}, {'type': 'Shots off Goal', 'value': 7}, {'type': 'Total Shots', 'value': 15}, {'type': 'Blocked Shots', 'value': 4}, {'type': 'Shots insidebox', 'value': 9}, {'type': 'Shots outsidebox', 'value': 6}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 7}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '58%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': 0}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 481}, {'type': 'Passes accurate', 'value': 393}, {'type': 'Passes %', 'value': '82%'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 2}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 12}, {'type': 'Blocked Shots', 'value': 7}, {'type': 'Shots insidebox', 'value': 8}, {'type': 'Shots outsidebox', 'value': 4}, {'type': 'Fouls', 'value': 13}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '42%'}, {'type': 'Yellow Cards', 'value': 5}, {'type': 'Red Cards', 'value': 1}, {'type': 'Goalkeeper Saves', 'value': 4}, {'type': 'Total passes', 'value': 356}, {'type': 'Passes accurate', 'value': 272}, {'type': 'Passes %', 'value': '76%'}]}]
# Index No: 22
# ID partido: 710806
# Enpoint: fixtures/statistics?fixture=710806&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# ...
# Index No: 264
# ID partido: 1379295
# Enpoint: fixtures/statistics?fixture=1379295&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 50, 'name': 'Manchester City', 'logo': 'https://media.api-sports.io/football/teams/50.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 5}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 15}, {'type': 'Blocked Shots', 'value': 5}, {'type': 'Shots insidebox', 'value': 13}, {'type': 'Shots outsidebox', 'value': 2}, {'type': 'Fouls', 'value': 5}, {'type': 'Corner Kicks', 'value': 8}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '59%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 498}, {'type': 'Passes accurate', 'value': 424}, {'type': 'Passes %', 'value': '85%'}, {'type': 'expected_goals', 'value': '1.36'}, {'type': 'goals_prevented', 'value': '-0.64'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 9}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 8}, {'type': 'Shots outsidebox', 'value': 1}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 5}, {'type': 'Offsides', 'value': 4}, {'type': 'Ball Possession', 'value': '41%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 348}, {'type': 'Passes accurate', 'value': 262}, {'type': 'Passes %', 'value': '75%'}, {'type': 'expected_goals', 'value': '1.62'}, {'type': 'goals_prevented', 'value': '-0.64'}]}]
# Index No: 265
# ID partido: 1379299
# Enpoint: fixtures/statistics?fixture=1379299&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 4}, {'type': 'Shots off Goal', 'value': 2}, {'type': 'Total Shots', 'value': 11}, {'type': 'Blocked Shots', 'value': 5}, {'type': 'Shots insidebox', 'value': 6}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 13}, {'type': 'Corner Kicks', 'value': 7}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '45%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 400}, {'type': 'Passes accurate', 'value': 323}, {'type': 'Passes %', 'value': '81%'}, {'type': 'expected_goals', 'value': '0.49'}, {'type': 'goals_prevented', 'value': '-0.13'}]}, {'team': {'id': 34, 'name': 'Newcastle', 'logo': 'https://media.api-sports.io/football/teams/34.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 5}, {'type': 'Total Shots', 'value': 13}, {'type': 'Blocked Shots', 'value': 5}, {'type': 'Shots insidebox', 'value': 6}, {'type': 'Shots outsidebox', 'value': 7}, {'type': 'Fouls', 'value': 10}, {'type': 'Corner Kicks', 'value': 2}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '55%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 486}, {'type': 'Passes accurate', 'value': 415}, {'type': 'Passes %', 'value': '85%'}, {'type': 'expected_goals', 'value': '1.00'}, {'type': 'goals_prevented', 'value': '-0.13'}]}]
# Index No: 230
# ID partido: 1540842
# Enpoint: fixtures/statistics?fixture=1540842&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 530, 'name': 'Atletico Madrid', 'logo': 'https://media.api-sports.io/football/teams/530.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 4}, {'type': 'Shots off Goal', 'value': 8}, {'type': 'Total Shots', 'value': 18}, {'type': 'Blocked Shots', 'value': 6}, {'type': 'Shots insidebox', 'value': 13}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 7}, {'type': 'Corner Kicks', 'value': 6}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '52%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 505}, {'type': 'Passes accurate', 'value': 420}, {'type': 'Passes %', 'value': '83%'}, {'type': 'expected_goals', 'value': '2.21'}, {'type': 'goals_prevented', 'value': '0.76'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 2}, {'type': 'Shots off Goal', 'value': 4}, {'type': 'Total Shots', 'value': 11}, {'type': 'Blocked Shots', 'value': 5}, {'type': 'Shots insidebox', 'value': 8}, {'type': 'Shots outsidebox', 'value': 3}, {'type': 'Fouls', 'value': 11}, {'type': 'Corner Kicks', 'value': 1}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '48%'}, {'type': 'Yellow Cards', 'value': 0}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 480}, {'type': 'Passes accurate', 'value': 423}, {'type': 'Passes %', 'value': '88%'}, {'type': 'expected_goals', 'value': '1.51'}, {'type': 'goals_prevented', 'value': '0.76'}]}]
# Index No: 266
# ID partido: 1379309
# Enpoint: fixtures/statistics?fixture=1379309&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 9}, {'type': 'Shots off Goal', 'value': 6}, {'type': 'Total Shots', 'value': 18}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 14}, {'type': 'Shots outsidebox', 'value': 4}, {'type': 'Fouls', 'value': 7}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': 7}, {'type': 'Ball Possession', 'value': '54%'}, {'type': 'Yellow Cards', 'value': 0}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 511}, {'type': 'Passes accurate', 'value': 453}, {'type': 'Passes %', 'value': '89%'}, {'type': 'expected_goals', 'value': '3.23'}, {'type': 'goals_prevented', 'value': '0.66'}]}, {'team': {'id': 36, 'name': 'Fulham', 'logo': 'https://media.api-sports.io/football/teams/36.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 1}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 10}, {'type': 'Blocked Shots', 'value': 6}, {'type': 'Shots insidebox', 'value': 5}, {'type': 'Shots outsidebox', 'value': 5}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '46%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 6}, {'type': 'Total passes', 'value': 433}, {'type': 'Passes accurate', 'value': 359}, {'type': 'Passes %', 'value': '83%'}, {'type': 'expected_goals', 'value': '0.37'}, {'type': 'goals_prevented', 'value': '0.66'}]}]
# Index No: 231
# ID partido: 1540843
# Enpoint: fixtures/statistics?fixture=1540843&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 2}, {'type': 'Shots off Goal', 'value': 8}, {'type': 'Total Shots', 'value': 13}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 6}, {'type': 'Shots outsidebox', 'value': 7}, {'type': 'Fouls', 'value': 10}, {'type': 'Corner Kicks', 'value': 5}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '53%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 445}, {'type': 'Passes accurate', 'value': 378}, {'type': 'Passes %', 'value': '85%'}, {'type': 'expected_goals', 'value': '1.56'}, {'type': 'goals_prevented', 'value': '0.21'}]}, {'team': {'id': 530, 'name': 'Atletico Madrid', 'logo': 'https://media.api-sports.io/football/teams/530.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 2}, {'type': 'Shots off Goal', 'value': 4}, {'type': 'Total Shots', 'value': 9}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 7}, {'type': 'Shots outsidebox', 'value': 2}, {'type': 'Fouls', 'value': 13}, {'type': 'Corner Kicks', 'value': 2}, {'type': 'Offsides', 'value': 2}, {'type': 'Ball Possession', 'value': '47%'}, {'type': 'Yellow Cards', 'value': 2}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 386}, {'type': 'Passes accurate', 'value': 320}, {'type': 'Passes %', 'value': '83%'}, {'type': 'expected_goals', 'value': '0.99'}, {'type': 'goals_prevented', 'value': '0.21'}]}]
# Index No: 267
# ID partido: 1379328
# Enpoint: fixtures/statistics?fixture=1379328&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 48, 'name': 'West Ham', 'logo': 'https://media.api-sports.io/football/teams/48.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 2}, {'type': 'Total Shots', 'value': 9}, {'type': 'Blocked Shots', 'value': 4}, {'type': 'Shots insidebox', 'value': 6}, {'type': 'Shots outsidebox', 'value': 3}, {'type': 'Fouls', 'value': 14}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': None}, {'type': 'Ball Possession', 'value': '36%'}, {'type': 'Yellow Cards', 'value': 3}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 1}, {'type': 'Total passes', 'value': 283}, {'type': 'Passes accurate', 'value': 187}, {'type': 'Passes %', 'value': '66%'}, {'type': 'expected_goals', 'value': '1.15'}, {'type': 'goals_prevented', 'value': '0.79'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 4}, {'type': 'Shots off Goal', 'value': 6}, {'type': 'Total Shots', 'value': 15}, {'type': 'Blocked Shots', 'value': 5}, {'type': 'Shots insidebox', 'value': 9}, {'type': 'Shots outsidebox', 'value': 6}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': None}, {'type': 'Ball Possession', 'value': '64%'}, {'type': 'Yellow Cards', 'value': 4}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 3}, {'type': 'Total passes', 'value': 500}, {'type': 'Passes accurate', 'value': 416}, {'type': 'Passes %', 'value': '83%'}, {'type': 'expected_goals', 'value': '1.18'}, {'type': 'goals_prevented', 'value': '0.79'}]}]
# Index No: 268
# ID partido: 1379329
# Enpoint: fixtures/statistics?fixture=1379329&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 7}, {'type': 'Total Shots', 'value': 13}, {'type': 'Blocked Shots', 'value': 3}, {'type': 'Shots insidebox', 'value': 9}, {'type': 'Shots outsidebox', 'value': 4}, {'type': 'Fouls', 'value': 7}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '60%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 0}, {'type': 'Total passes', 'value': 513}, {'type': 'Passes accurate', 'value': 444}, {'type': 'Passes %', 'value': '87%'}, {'type': 'expected_goals', 'value': '1.29'}, {'type': 'goals_prevented', 'value': '1.03'}]}, {'team': {'id': 44, 'name': 'Burnley', 'logo': 'https://media.api-sports.io/football/teams/44.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 0}, {'type': 'Shots off Goal', 'value': 4}, {'type': 'Total Shots', 'value': 5}, {'type': 'Blocked Shots', 'value': 1}, {'type': 'Shots insidebox', 'value': 2}, {'type': 'Shots outsidebox', 'value': 3}, {'type': 'Fouls', 'value': 16}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '40%'}, {'type': 'Yellow Cards', 'value': 3}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 336}, {'type': 'Passes accurate', 'value': 266}, {'type': 'Passes %', 'value': '79%'}, {'type': 'expected_goals', 'value': '0.19'}, {'type': 'goals_prevented', 'value': '1.03'}]}]
# Index No: 269
# ID partido: 1379341
# Enpoint: fixtures/statistics?fixture=1379341&half=false
# No. errors:  0
# No. results:  2
# ----
#
#
#
# [{'team': {'id': 52, 'name': 'Crystal Palace', 'logo': 'https://media.api-sports.io/football/teams/52.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 3}, {'type': 'Shots off Goal', 'value': 3}, {'type': 'Total Shots', 'value': 8}, {'type': 'Blocked Shots', 'value': 2}, {'type': 'Shots insidebox', 'value': 8}, {'type': 'Shots outsidebox', 'value': 0}, {'type': 'Fouls', 'value': 9}, {'type': 'Corner Kicks', 'value': 3}, {'type': 'Offsides', 'value': 1}, {'type': 'Ball Possession', 'value': '40%'}, {'type': 'Yellow Cards', 'value': 0}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 5}, {'type': 'Total passes', 'value': 328}, {'type': 'Passes accurate', 'value': 261}, {'type': 'Passes %', 'value': '80%'}, {'type': 'expected_goals', 'value': '0.98'}, {'type': 'goals_prevented', 'value': '-0.06'}]}, {'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'statistics': [{'type': 'Shots on Goal', 'value': 7}, {'type': 'Shots off Goal', 'value': 6}, {'type': 'Total Shots', 'value': 17}, {'type': 'Blocked Shots', 'value': 4}, {'type': 'Shots insidebox', 'value': 14}, {'type': 'Shots outsidebox', 'value': 3}, {'type': 'Fouls', 'value': 12}, {'type': 'Corner Kicks', 'value': 4}, {'type': 'Offsides', 'value': 0}, {'type': 'Ball Possession', 'value': '60%'}, {'type': 'Yellow Cards', 'value': 1}, {'type': 'Red Cards', 'value': None}, {'type': 'Goalkeeper Saves', 'value': 2}, {'type': 'Total passes', 'value': 518}, {'type': 'Passes accurate', 'value': 460}, {'type': 'Passes %', 'value': '89%'}, {'type': 'expected_goals', 'value': '2.53'}, {'type': 'goals_prevented', 'value': '-0.06'}]}]
# 284/19

# %% [markdown]
# Nota: Convertirmos la columna 'ball_possession' y 'passes_percentage' a un valor floante/numérico (quitando el símbolo de porcentaje)

# %%
df_fixtures_all_sessons_stats['ball_possession'] = df_fixtures_all_sessons_stats['ball_possession'].str.replace('%', '').astype(float) / 100

df_fixtures_all_sessons_stats['passes_percentage'] = df_fixtures_all_sessons_stats['passes_percentage'].str.replace('%', '').astype(float) / 100

df_fixtures_all_sessons_stats[['passes_percentage', 'ball_possession']].head(2)
# Out:
#    passes_percentage  ball_possession
# 0               0.86             0.65
# 1               0.79             0.35

# %%
df_fixtures_all_sessons_stats['corner_kicks'] = pd.to_numeric(df_fixtures_all_sessons_stats['corner_kicks'], errors='coerce')
df_fixtures_all_sessons_stats['offsides'] = pd.to_numeric(df_fixtures_all_sessons_stats['offsides'], errors='coerce')
df_fixtures_all_sessons_stats['yellow_cards'] = pd.to_numeric(df_fixtures_all_sessons_stats['yellow_cards'], errors='coerce')


df_fixtures_all_sessons_stats[['corner_kicks', 'offsides', 'yellow_cards']].head(2)
# Out:
#    corner_kicks  offsides  yellow_cards
# 0           5.0       1.0           NaN
# 1           9.0       5.0           3.0

# %%
df = df_fixtures_all_sessons_stats.copy()

# %% [markdown]
# ### **<font color='orange'>Primer vistazo</font>**

# %%
print(f"{len(df_no_match_information)} matches have not information about it")

print(f"\n\n{df.shape}\n\n")

df.head()
# Out:
# 19 matches have not information about it
#
#
# (265, 21)
#    team_id team_name  total_shots  shots_on_goal  fouls  corner_kicks  \
# 0       42   Arsenal           22              4      8           5.0
# 1       42   Arsenal            6              3     10           9.0
# 2       42   Arsenal           14              9      5           3.0
# 3       42   Arsenal            1              0      7           0.0
# 4       42   Arsenal           30              7      9           8.0
#
#    offsides  ball_possession  yellow_cards goalkeeper_saves  ...  \
# 0       1.0             0.65           NaN                1  ...
# 1       5.0             0.35           3.0                3  ...
# 2       2.0             0.74           2.0                4  ...
# 3       3.0             0.20           2.0                5  ...
# 4       2.0             0.52           1.0                1  ...
#
#    total_passes  passes_accurate  shots_received  shots_on_goal_received  \
# 0           568              488               8                       3
# 1           335              266              22                       5
# 2           640              566              11                       4
# 3           185              125              25                      10
# 4           437              365              10                       1
#
#    fixture_id  match_result goals_for  goals_against  is_home  season
# 0      710556         False         0              2    False    2021
# 1      710566         False         0              2     True    2021
# 2      766563          True         6              0    False    2021
# 3      710580         False         0              5    False    2021
# 4      710586          True         1              0     True    2021
#
# [5 rows x 21 columns]

# %% [markdown]
# ### **<font color='orange'>Descripción general de la forma y los tipos de datos</font>**

# %%
print("Dimensiones del dataset de partidos:", df.shape)
print("\nColumnas disponibles:")
display(df.columns.tolist())

print("\nTipos de datos:")
print(df.dtypes)

display(df.head())
# Out:
# Dimensiones del dataset de partidos: (265, 21)
#
# Columnas disponibles:
# ['team_id',
#  'team_name',
#  'total_shots',
#  'shots_on_goal',
#  'fouls',
#  'corner_kicks',
#  'offsides',
#  'ball_possession',
#  'yellow_cards',
#  'goalkeeper_saves',
#  'passes_percentage',
#  'total_passes',
#  'passes_accurate',
#  'shots_received',
#  'shots_on_goal_received',
#  'fixture_id',
#  'match_result',
#  'goals_for',
#  'goals_against',
#  'is_home',
#  'season']
# Tipos de datos:
# team_id                     int64
# team_name                  object
# total_shots                 int64
# shots_on_goal               int64
# fouls                       int64
# corner_kicks              float64
# offsides                  float64
# ball_possession           float64
# yellow_cards              float64
# goalkeeper_saves           object
# passes_percentage         float64
# total_passes                int64
# passes_accurate             int64
# shots_received              int64
# shots_on_goal_received      int64
# fixture_id                  int64
# match_result               object
# goals_for                   int64
# goals_against               int64
# is_home                      bool
# season                      int64
# dtype: object
#    team_id team_name  total_shots  shots_on_goal  fouls  corner_kicks  \
# 0       42   Arsenal           22              4      8           5.0
# 1       42   Arsenal            6              3     10           9.0
# 2       42   Arsenal           14              9      5           3.0
# 3       42   Arsenal            1              0      7           0.0
# 4       42   Arsenal           30              7      9           8.0
#
#    offsides  ball_possession  yellow_cards goalkeeper_saves  ...  \
# 0       1.0             0.65           NaN                1  ...
# 1       5.0             0.35           3.0                3  ...
# 2       2.0             0.74           2.0                4  ...
# 3       3.0             0.20           2.0                5  ...
# 4       2.0             0.52           1.0                1  ...
#
#    total_passes  passes_accurate  shots_received  shots_on_goal_received  \
# 0           568              488               8                       3
# 1           335              266              22                       5
# 2           640              566              11                       4
# 3           185              125              25                      10
# 4           437              365              10                       1
#
#    fixture_id  match_result goals_for  goals_against  is_home  season
# 0      710556         False         0              2    False    2021
# 1      710566         False         0              2     True    2021
# 2      766563          True         6              0    False    2021
# 3      710580         False         0              5    False    2021
# 4      710586          True         1              0     True    2021
#
# [5 rows x 21 columns]

# %% [markdown]
# ### **<font color='orange'>Valores faltantes en el conjunto de datos</font>**

# %%
missing_count = df.isnull().sum()
missing_percent = (df.isnull().mean() * 100).round(2)

missing_summary = pd.DataFrame({
    "missing_count": missing_count,
    "missing_percent": missing_percent
})

display(missing_summary)

sns.heatmap(df.isnull(), cbar=False)
plt.title("Mapa de valores faltantes FÚBTOL")
plt.show()
# Out:
#                         missing_count  missing_percent
# team_id                             0             0.00
# team_name                           0             0.00
# total_shots                         0             0.00
# shots_on_goal                       0             0.00
# fouls                               0             0.00
# corner_kicks                        1             0.38
# offsides                           12             4.53
# ball_possession                     0             0.00
# yellow_cards                       12             4.53
# goalkeeper_saves                    1             0.38
# passes_percentage                   0             0.00
# total_passes                        0             0.00
# passes_accurate                     0             0.00
# shots_received                      0             0.00
# shots_on_goal_received              0             0.00
# fixture_id                          0             0.00
# match_result                       45            16.98
# goals_for                           0             0.00
# goals_against                       0             0.00
# is_home                             0             0.00
# season                              0             0.00

# %% [markdown]
# ### **<font color='orange'>Estadísticas descriptivas y de frecuencia</font>**

# %%
df.drop(columns=['team_id', 'fixture_id', 'season']).describe().T
# Out:
#                         count        mean         std    min     25%     50%  \
# total_shots             265.0   15.022642    5.605011   1.00   11.00   14.00
# shots_on_goal           265.0    5.275472    2.630597   0.00    3.00    5.00
# fouls                   265.0   10.139623    3.478197   0.00    8.00   10.00
# corner_kicks            264.0    6.015152    3.214712   0.00    4.00    5.00
# offsides                253.0    1.849802    1.469657   0.00    1.00    2.00
# ball_possession         265.0    0.566566    0.114841   0.20    0.49    0.57
# yellow_cards            253.0    1.648221    1.246729   0.00    1.00    1.00
# passes_percentage       265.0    0.847774    0.049810   0.49    0.83    0.86
# total_passes            265.0  501.626415  117.682933  88.00  433.00  500.00
# passes_accurate         265.0  429.667925  117.158866  69.00  360.00  424.00
# shots_received          265.0    9.456604    4.571714   1.00    6.00    9.00
# shots_on_goal_received  265.0    3.049057    1.948545   0.00    2.00    3.00
# goals_for               265.0    2.003774    1.511316   0.00    1.00    2.00
# goals_against           265.0    0.924528    0.966269   0.00    0.00    1.00
#
#                            75%     max
# total_shots              18.00   36.00
# shots_on_goal             7.00   16.00
# fouls                    12.00   22.00
# corner_kicks              8.00   17.00
# offsides                  3.00    8.00
# ball_possession           0.65    0.82
# yellow_cards              2.00    6.00
# passes_percentage         0.88    0.93
# total_passes            581.00  895.00
# passes_accurate         503.00  827.00
# shots_received           12.00   33.00
# shots_on_goal_received    4.00   11.00
# goals_for                 3.00    7.00
# goals_against             2.00    5.00

# %% [markdown]
# Nota: Match result se divide en
#
# 1.   True: Partido ganado
# 2.   False: Partido perdido
# 3.   None: Partido empatado

# %%
df.drop(columns=['team_id', 'fixture_id']).describe(include=['object', 'bool']).T
# Out:
#                  count unique      top freq
# team_name          265      1  Arsenal  265
# goalkeeper_saves   264     10        1   78
# match_result       220      2     True  169
# is_home            265      2    False  134

# %%
display(df['match_result'].value_counts(dropna=False))
# Out:
# match_result
# True     169
# False     51
# None      45
# Name: count, dtype: int64

# %% [markdown]
# ### Hacer el resultado del partido en categorías tipo 'one-hot-encoding'
#
# * Victoria = 2
# * Empate = 1
# * Derrota = 0

# %%
df['is_home'] = pd.Categorical(df['is_home'],
                                    categories=[True, False])

df['match_result'] = pd.Categorical(df['match_result'],
                                    categories=[True, False])

df_dummies = pd.get_dummies(df['match_result'],
                            prefix='res',
                            dummy_na=True)

df_dummies = df_dummies.rename(columns={
    'res_True': 'victoria',
    'res_False': 'derrota',
    'res_nan': 'empate'
})

df = pd.concat([df,
                df_dummies], axis=1)

mapping = {
    'victoria': 2, # Changed from 3 to 2
    'empate': 1,
    'derrota': 0
}

df['result_num'] = df[['victoria', 'empate', 'derrota']].idxmax(axis=1).map(mapping)

df.head(25)
# Out:
#     team_id team_name  total_shots  shots_on_goal  fouls  corner_kicks  \
# 0        42   Arsenal           22              4      8           5.0
# 1        42   Arsenal            6              3     10           9.0
# 2        42   Arsenal           14              9      5           3.0
# 3        42   Arsenal            1              0      7           0.0
# 4        42   Arsenal           30              7      9           8.0
# 5        42   Arsenal           13              3      8           3.0
# 6        42   Arsenal           19              5      8          10.0
# 7        42   Arsenal           12              7     12           4.0
# 8        42   Arsenal            8              2      5           5.0
# 9        42   Arsenal           17              6      7           6.0
# 10       42   Arsenal           22              9     17           7.0
# 11       42   Arsenal           14              4      5          10.0
# 12       42   Arsenal            9              5     11           6.0
# 13       42   Arsenal           14              6      6           4.0
# 14       42   Arsenal            5              3     12           1.0
# 15       42   Arsenal           24              6      6           4.0
# 16       42   Arsenal           17              8     10           8.0
# 17       42   Arsenal           10              3     12           3.0
# 18       42   Arsenal           15              5      5           9.0
# 19       42   Arsenal           21              8      9           5.0
# 20       42   Arsenal           21             12      7           4.0
# 21       42   Arsenal           19             10     10           2.0
# 22       42   Arsenal           16              6      7           4.0
# 23       42   Arsenal            7              2     13           5.0
# 24       42   Arsenal           10              0     11           6.0
#
#     offsides  ball_possession  yellow_cards goalkeeper_saves  ...  fixture_id  \
# 0        1.0             0.65           NaN                1  ...      710556
# 1        5.0             0.35           3.0                3  ...      710566
# 2        2.0             0.74           2.0                4  ...      766563
# 3        3.0             0.20           2.0                5  ...      710580
# 4        2.0             0.52           1.0                1  ...      710586
# 5        2.0             0.55           1.0                3  ...      710598
# 6        2.0             0.62           0.0                0  ...      787058
# 7        2.0             0.47           2.0                3  ...      710606
# 8        1.0             0.42           1.0                2  ...      710616
# 9        0.0             0.54           1.0                4  ...      710626
# 10       1.0             0.54           2.0                3  ...      710636
# 11       3.0             0.45           1.0                5  ...      800353
# 12       1.0             0.36           0.0                8  ...      710648
# 13       3.0             0.61           4.0                1  ...      710656
# 14       8.0             0.37           0.0                5  ...      710669
# 15       0.0             0.66           1.0                5  ...      710676
# 16       1.0             0.55           0.0                7  ...      710692
# 17       1.0             0.64           2.0                3  ...      710697
# 18       3.0             0.61           2.0                6  ...      710706
# 19       NaN             0.56           2.0                1  ...      710716
# 20       1.0             0.49           1.0                1  ...      710728
# 21       2.0             0.68           1.0                5  ...      810061
# 22       2.0             0.65           2.0                2  ...      710742
# 23       1.0             0.29           5.0                0  ...      710756
# 24       2.0             0.67           1.0                2  ...      815169
#
#     match_result  goals_for  goals_against  is_home  season victoria  derrota  \
# 0          False          0              2    False    2021    False     True
# 1          False          0              2     True    2021    False     True
# 2           True          6              0    False    2021     True    False
# 3          False          0              5    False    2021    False     True
# 4           True          1              0     True    2021     True    False
# 5           True          1              0    False    2021     True    False
# 6           True          3              0     True    2021     True    False
# 7           True          3              1     True    2021     True    False
# 8            NaN          0              0    False    2021    False    False
# 9            NaN          2              2     True    2021    False    False
# 10          True          3              1     True    2021     True    False
# 11          True          2              0     True    2021     True    False
# 12          True          2              0    False    2021     True    False
# 13          True          1              0     True    2021     True    False
# 14         False          0              4    False    2021    False     True
# 15          True          2              0     True    2021     True    False
# 16         False          2              3    False    2021    False     True
# 17         False          1              2    False    2021    False     True
# 18          True          3              0     True    2021     True    False
# 19          True          2              0     True    2021     True    False
# 20          True          4              1    False    2021     True    False
# 21          True          5              1     True    2021     True    False
# 22          True          5              0    False    2021     True    False
# 23         False          1              2     True    2021    False     True
# 24         False          0              1    False    2021    False     True
#
#     empate result_num
# 0    False          0
# 1    False          0
# 2    False          2
# 3    False          0
# 4    False          2
# 5    False          2
# 6    False          2
# 7    False          2
# 8     True          1
# 9     True          1
# 10   False          2
# 11   False          2
# 12   False          2
# 13   False          2
# 14   False          0
# 15   False          2
# 16   False          0
# 17   False          0
# 18   False          2
# 19   False          2
# 20   False          2
# 21   False          2
# 22   False          2
# 23   False          0
# 24   False          0
#
# [25 rows x 25 columns]

# %% [markdown]
# ### Eliminamos columnas que repiten información o cuyo valor no es relevante

# %%
columns_to_drop = ['team_id', 'team_name', 'fixture_id',
                   'match_result',
                   'victoria', 'derrota', 'empate']

df = df.drop(columns_to_drop, axis=1)

df.head(2)
# Out:
#    total_shots  shots_on_goal  fouls  corner_kicks  offsides  ball_possession  \
# 0           22              4      8           5.0       1.0             0.65
# 1            6              3     10           9.0       5.0             0.35
#
#    yellow_cards goalkeeper_saves  passes_percentage  total_passes  \
# 0           NaN                1               0.86           568
# 1           3.0                3               0.79           335
#
#    passes_accurate  shots_received  shots_on_goal_received  goals_for  \
# 0              488               8                       3          0
# 1              266              22                       5          0
#
#    goals_against is_home  season  result_num
# 0              2   False    2021           0
# 1              2    True    2021           0

# %% [markdown]
# ### **<font color='pink'>Matriz de correlación</font>**

# %%
numeric_df = df.select_dtypes(include=[np.number])
corr_matrix = numeric_df.corr()

# Crear una máscara para la mitad superior
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

plt.figure(figsize=(50, 40))
sns.heatmap(
    corr_matrix,
    mask=mask,       # Aplicar la máscara
    annot=True,
    cmap='coolwarm',
    vmin=-1,
    vmax=1,
    linewidths=0.5
)
plt.show()

# %%
plt.figure(figsize=(10, 12))

# Ordenamos las correlaciones respecto a 'result_num'
res_corr = corr_matrix[['result_num']].sort_values(by='result_num', ascending=False)

sns.heatmap(
    res_corr,
    annot=True,
    cmap='RdYlGn', # Verde para correlación positiva (victoria), rojo para negativa
    vmin=-1, vmax=1,
    fmt=".2f"
)

plt.title('Influencia de variables en el Resultado\n(2=Vic, 1=Emp, 0=Der)')
plt.show()

# %%
# 1. Creamos variables temporales binarias (1 si ocurre, 0 si no)
df_temp = df.copy()
df_temp['Victoria'] = (df_temp['result_num'] == 2).astype(int)
df_temp['Empate'] = (df_temp['result_num'] == 1).astype(int)
df_temp['Derrota'] = (df_temp['result_num'] == 0).astype(int)

# 2. Definimos las columnas de resultados y las estadísticas que ya tenías
col_resultados = ['Victoria', 'Empate', 'Derrota']
colums_analyze = ['fouls', 'yellow_cards', 'total_shots', 'shots_on_goal',
                  'ball_possession',
                  'goalkeeper_saves', 'passes_percentage', 'total_passes',
                  'passes_accurate', 'goals_for', 'goals_against']

# 3. Calculamos la correlación solo entre estadísticas y los resultados
corr_resultados = df_temp[colums_analyze + col_resultados].corr().loc[colums_analyze, col_resultados]

# 4. Graficamos el Heatmap aislado
plt.figure(figsize=(8, 10)) # Un tamaño más vertical y cómodo de leer
sns.heatmap(
    corr_resultados,
    annot=True,       # Muestra el número
    fmt=".2f",        # 2 decimales
    cmap='coolwarm',  # Azul (negativo), Rojo (positivo)
    vmin=-1, vmax=1,
    linewidths=0.5
)

plt.title('Correlación de cada Estadística vs Resultado del Partido', fontsize=14, pad=15)
plt.ylabel('Estadísticas del Partido')
plt.xlabel('Resultados')
plt.show()

# %% [markdown]
# ### **<font color='pink'>Outliers</font>**

# %%
colums_analyze = ['total_shots', 'shots_on_goal', 'ball_possession',
                  'goalkeeper_saves', 'passes_percentage', 'total_passes',
                  'passes_accurate', 'goals_for', 'goals_against']

# Configuramos el número de columnas y calculamos las filas necesarias
cols = 3
rows = math.ceil(len(colums_analyze) / cols)

# Creamos la base del cuadro (el lienzo grande)
fig, axes = plt.subplots(rows, cols, figsize=(18, rows * 5))
axes = axes.flatten() # Aplanamos la matriz de ejes para iterar fácilmente

for i, col in enumerate(colums_analyze):
    sns.boxplot(y=df[col], ax=axes[i], color='skyblue')
    axes[i].set_title(f'Outliers in {col}', fontsize=12)
    axes[i].set_ylabel('') # Limpiamos el nombre del eje Y para que se vea más estético

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **<font color='pink'>Victorias, Empates y Derrotas (local vs visitante)</font>**

# %%
match_is_home_count = df.groupby(['is_home', 'result_num']).size().unstack(fill_value=0)
match_is_home_count
# Out:
# /tmp/ipykernel_664/632641939.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   match_is_home_count = df.groupby(['is_home', 'result_num']).size().unstack(fill_value=0)
# result_num   0   1   2
# is_home
# True        18  18  95
# False       33  27  74

# %%
result = pd.crosstab(df['is_home'], df['result_num'], normalize='index')
result
# Out:
# result_num         0         1         2
# is_home
# True        0.137405  0.137405  0.725191
# False       0.246269  0.201493  0.552239

# %%
result.plot(kind='bar')

plt.title('Match results home or visit')
plt.xlabel('is_home (True = Local, False = Visitante)')
plt.ylabel('Proportion')
plt.legend(title='Resultado', labels=['Derrota', 'Empate', 'Victoria'], loc='upper left')
plt.xticks(rotation=0)

plt.show()

# %%
result_evolucion = pd.crosstab(index=[df['season'], df['is_home']],
                               columns=df['result_num'],
                               normalize='index')

ax = result_evolucion.plot(kind='bar', figsize=(12, 6), stacked=True)

plt.title('Resultados de partidos por Temporada (Local vs Visitante)')
plt.xlabel('Temporada e is_home (0=Visitante, 1=Local)')
plt.ylabel('Proporción')
plt.legend(title='Resultado', labels=['Derrota', 'Empate', 'Victoria'], loc='upper right')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **<font color='pink'>Histogramas</font>**

# %%
colums_analyze = ['total_shots', 'shots_on_goal', 'ball_possession',
                  'goalkeeper_saves', 'passes_percentage', 'total_passes',
                  'passes_accurate', 'goals_for', 'goals_against']

cols = 3
rows = math.ceil(len(colums_analyze) / cols)

fig, axes = plt.subplots(rows, cols, figsize=(18, rows * 5))
axes = axes.flatten()

for i, col in enumerate(colums_analyze):
    # Creamos el histograma
    # hue='result_num' separa por colores según el resultado
    # kde=True añade una línea de suavizado para ver mejor la tendencia
    sns.histplot(data=df,
                 x=col,
                 hue='result_num',
                 kde=True,
                 element="step",
                 ax=axes[i],
                 palette='viridis')

    axes[i].set_title(f'Distribución de {col} por Resultado', fontsize=12)
    axes[i].set_xlabel(f'{col}')
    axes[i].set_ylabel('Frecuencia (partidos)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **<font color='pink'>Valores nulos</font>**

# %%
sns.heatmap(df.isnull(),
            cbar=False,
            yticklabels=False,
            cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ### **<font color='green'>Preprocesamiento (Eliminar columunas con valores faltantes)</font>**

# %%
columns_drop = ['offsides', 'yellow_cards']

df_production = df.drop(columns_drop, axis=1)

df_production.head(2)
# Out:
#    total_shots  shots_on_goal  fouls  corner_kicks  ball_possession  \
# 0           22              4      8           5.0             0.65
# 1            6              3     10           9.0             0.35
#
#   goalkeeper_saves  passes_percentage  total_passes  passes_accurate  \
# 0                1               0.86           568              488
# 1                3               0.79           335              266
#
#    shots_received  shots_on_goal_received  goals_for  goals_against is_home  \
# 0               8                       3          0              2   False
# 1              22                       5          0              2    True
#
#    season  result_num
# 0    2021           0
# 1    2021           0

# %%
display(df_production.isnull().sum())
# Out:
# total_shots               0
# shots_on_goal             0
# fouls                     0
# corner_kicks              1
# ball_possession           0
# goalkeeper_saves          1
# passes_percentage         0
# total_passes              0
# passes_accurate           0
# shots_received            0
# shots_on_goal_received    0
# goals_for                 0
# goals_against             0
# is_home                   0
# season                    0
# result_num                0
# dtype: int64

# %% [markdown]
# ## 🔨 <font color=#258FE8>**Ingeniería de características**</font> (Avance 2)

# %% [markdown]
# ### Obtener dataset de partidos (información general)

# %%
df_api = get_general_results_matches_all_teams()
# Out:
# SEASON: 2021
# ID LEAGUE: 2
# No. errors:  0
# No. results:  218
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  177
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  380
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  868
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  93
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  6852
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  0
# ----
#
#
#
# SEASON: 2022
# ID LEAGUE: 2
# No. errors:  0
# No. results:  214
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  175
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  380
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  889
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  93
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  5509
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  1
# ----
#
#
#
# SEASON: 2023
# ID LEAGUE: 2
# No. errors:  0
# No. results:  214
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  175
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  380
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  879
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  93
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  8708
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  1
# ----
#
#
#
# SEASON: 2024
# ID LEAGUE: 2
# No. errors:  0
# No. results:  279
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  269
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  380
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  873
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  93
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  7564
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  1
# ----
#
#
#
# SEASON: 2025
# ID LEAGUE: 2
# No. errors:  0
# No. results:  281
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  271
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  380
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  872
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  93
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  5360
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  1
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  1
# ----
#
#
#
# SEASON: 2026
# ID LEAGUE: 2
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 3
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 39
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 45
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 48
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 528
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 667
# No. errors:  0
# No. results:  3849
# ----
#
#
#
# ID LEAGUE: 866
# No. errors:  0
# No. results:  0
# ----
#
#
#
# ID LEAGUE: 937
# No. errors:  0
# No. results:  0
# ----

# %%
df = df_api.copy()

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(by='date').reset_index(drop=True)
display(df.shape)
display(df.head(2))
# Out:
# (41654, 7)
#    fixture_id  season                      date        home_team away_team  \
# 0      738437    2021 2021-01-01 09:00:00+00:00  Sanna Khanh Hoa   Da Nang
# 1      738438    2021 2021-01-01 11:00:00+00:00       Binh Duong  Nam Dinh
#
#    home_goals  away_goals
# 0           2           3
# 1           2           1

# %% [markdown]
# ### **<font color='orange'>ELO Ranking avanzado</font>**

# %% [markdown]
# #### Inicializamos a todos los equipos otorgando un valor inicial de 1,500 pts

# %%
teams = pd.concat([df['home_team'], df['away_team']]).unique()
elo_dictionary = {team: 1500 for team in teams}
elo_dictionary
# Out:
# {'Sanna Khanh Hoa': 1500,
#  'Binh Duong': 1500,
#  'Ho Chi Minh': 1500,
#  'Sai Gon': 1500,
#  'Alondras': 1500,
#  'Nam Dinh': 1500,
#  'Hoang Anh Gia Lai': 1500,
#  'Soroksar': 1500,
#  'Laredo': 1500,
#  'Litex': 1500,
#  'Renova': 1500,
#  'Chemik Bydgoszcz': 1500,
#  'Lokomotiv Sofia': 1500,
#  'Akademija Pandev': 1500,
#  'Bytovia Bytów': 1500,
#  'Śląsk Wrocław II': 1500,
#  'Pirin Blagoevgrad': 1500,
#  'Hebar 1918': 1500,
#  'Sesvete': 1500,
#  'Belasitsa': 1500,
#  'Borec': 1500,
#  'Opatija': 1500,
#  'Pogoń Siedlce': 1500,
#  'Drita': 1500,
#  'Belasica': 1500,
#  'CSM Reşiţa': 1500,
#  'Strumska Slava': 1500,
#  'Petrolul Ploiesti': 1500,
#  'Spartak Pleven': 1500,
#  'Podbrezová': 1500,
#  'Progresul Spartac': 1500,
#  'Gyirmot SE': 1500,
#  'Polonia Bytom': 1500,
#  'Olimpia Elbląg': 1500,
#  'Žilina II': 1500,
#  'Radomiak Radom': 1500,
#  'Sokół Ostróda': 1500,
#  'Elana Toruń': 1500,
#  'Yambol 1915': 1500,
#  'FK Rabotnicki': 1500,
#  'FUS Rabat': 1500,
#  'Szombathelyi Haladas': 1500,
#  'GKS Katowice': 1500,
#  'LDU de Quito': 1500,
#  'Ohrid': 1500,
#  'Struga': 1500,
#  'Slovan Bratislava II': 1500,
#  'Dubrava Zagreb': 1500,
#  'Chojniczanka Chojnice': 1500,
#  'Rapid': 1500,
#  'Kolubara': 1500,
#  'Kozuv Gevgelija': 1500,
#  'Bałtyk Gdynia': 1500,
#  'Gwarek Tarnowskie Góry': 1500,
#  'CSA Steaua Bucureşti': 1500,
#  'Farul Constanta': 1500,
#  'Pelister': 1500,
#  'Concordia': 1500,
#  'Emelec': 1500,
#  'Teteks': 1500,
#  'Radunia Stężyca': 1500,
#  'Ludogorets II': 1500,
#  'HNK Hajduk Split II': 1500,
#  'Kustosija': 1500,
#  'Essentuki': 1500,
#  'Dunav Ruse': 1500,
#  'FK Trayal': 1500,
#  'Hutnik Kraków': 1500,
#  'Pomorzanin Toruń': 1500,
#  'FK Zalgiris Vilnius': 1500,
#  'Ustrem Donchevo': 1500,
#  'Hrvatski Dragovoljac': 1500,
#  'Druzhba': 1500,
#  'Legia Warszawa II': 1500,
#  'Manta FC': 1500,
#  'Sportist Svoge': 1500,
#  'Sloga Vinica': 1500,
#  'Merani Martvili': 1500,
#  'Ripensia Timisoara': 1500,
#  'Guayaquil City FC': 1500,
#  'Dunarea Calarasi': 1500,
#  'Spartak Varna': 1500,
#  'Suduva Marijampole': 1500,
#  'Zagłębie Lubin II': 1500,
#  'Skalica': 1500,
#  'Borac Cacak': 1500,
#  'U Craiova 1948': 1500,
#  'Inter Dobrich': 1500,
#  'Ružomberok II': 1500,
#  'FK Sarajevo': 1500,
#  'FC Dnepr Mogilev': 1500,
#  'Chernomorets': 1500,
#  'Pandurii TG JIU': 1500,
#  'Nesebar': 1500,
#  'Mashuk-KMV': 1500,
#  'Radnicki 1923': 1500,
#  'Olimpia Grudziądz': 1500,
#  'CS Mioveni': 1500,
#  'Panevėžys': 1500,
#  'Wikielec': 1500,
#  'Treze': 1500,
#  'Kuban Kholding': 1500,
#  'Barcelona SC': 1500,
#  'Krylya Sovetov II': 1500,
#  'Zenit Izhevsk': 1500,
#  'Spartak Nalchik': 1500,
#  'Campinense': 1500,
#  'Lokomotivi Tbilisi': 1500,
#  'Filiaşi': 1500,
#  'Ryazan': 1500,
#  'Inter Cherkessk': 1500,
#  'Concordia Elbląg': 1500,
#  'Novosibirsk': 1500,
#  'Zvezda Perm': 1500,
#  'Puerto Cabello': 1500,
#  'Extremadura': 1500,
#  'Deportivo Lara': 1500,
#  'Nafta': 1500,
#  'FK Sokol Saratov': 1500,
#  'Mladost Ždralovi': 1500,
#  'Fundación Lara Deportiva': 1500,
#  'Portuguesa FC': 1500,
#  'FC Politehnica Timisoara': 1500,
#  'Kaluga': 1500,
#  'Luki-Energiya': 1500,
#  'Khimik-Arsenal': 1500,
#  'Orenburg II': 1500,
#  'Bellinzona': 1500,
#  'Saturn Ramenskoye': 1500,
#  'Torns': 1500,
#  'Alcoyano': 1500,
#  'Denizlispor': 1500,
#  'Solares': 1500,
#  'Inter Miami': 1500,
#  'Chicago Fire': 1500,
#  'New England Revolution': 1500,
#  'CF Montreal': 1500,
#  'San Jose Earthquakes': 1500,
#  'Orlando City SC': 1500,
#  'Austin Bold': 1500,
#  'Klubi-04': 1500,
#  'VPS': 1500,
#  'MP': 1500,
#  'FF Jaro': 1500,
#  'Lahti': 1500,
#  'Gnistan': 1500,
#  'EIF': 1500,
#  'Turku PS': 1500,
#  'Vancouver Whitecaps': 1500,
#  'New York City FC': 1500,
#  'New York Red Bulls': 1500,
#  'Pittsburgh Riverhounds': 1500,
#  'Los Angeles FC': 1500,
#  'New Mexico United': 1500,
#  'OKC Energy': 1500,
#  'Austin': 1500,
#  'FC Dallas': 1500,
#  'Seattle Sounders': 1500,
#  'Rops': 1500,
#  'El Paso Locomotive': 1500,
#  'Louisville City': 1500,
#  'Sirius': 1500,
#  'Haka': 1500,
#  'HJK Helsinki': 1500,
#  'Hartford Athletic': 1500,
#  'Charleston Battery': 1500,
#  'Rosenborg': 1500,
#  'Mjondalen': 1500,
#  'Start': 1500,
#  'Molde': 1500,
#  'Sogndal': 1500,
#  'Kristiansund BK': 1500,
#  'ODD Ballklubb': 1500,
#  'SJK': 1500,
#  'Viking': 1500,
#  'Inter Turku': 1500,
#  'jerv': 1500,
#  'North Texas': 1500,
#  'Indy Eleven': 1500,
#  'Orange County SC': 1500,
#  'Greenville Triumph': 1500,
#  'Tulsa Roughnecks': 1500,
#  'Union Omaha': 1500,
#  'Birmingham Legion': 1500,
#  'Honka Akatemia': 1500,
#  'Bodo/Glimt': 1500,
#  'JIPPO': 1500,
#  'Sarpsborg 08 FF': 1500,
#  'Stromsgodset': 1500,
#  'Fredrikstad': 1500,
#  'Ham-Kam': 1500,
#  'Aalesund': 1500,
#  'Valerenga': 1500,
#  'Sandnes ULF': 1500,
#  'Raufoss': 1500,
#  'North Carolina': 1500,
#  'Oostende': 1500,
#  'Kooteepee': 1500,
#  'Ilves': 1500,
#  'JJK': 1500,
#  'Strommen': 1500,
#  'Sporting KC II': 1500,
#  'San Antonio': 1500,
#  'Memphis 901': 1500,
#  'Phoenix Rising': 1500,
#  'Sacramento Republic': 1500,
#  'Haugesund': 1500,
#  'Philadelphia Union II': 1500,
#  'Brann': 1500,
#  'SJK Akatemia': 1500,
#  'Bryne': 1500,
#  'Ranheim': 1500,
#  'Stabaek': 1500,
#  'Asane': 1500,
#  'North Alabama': 1500,
#  'Brighouse Town': 1500,
#  'Halesowen Town': 1500,
#  'Golcar United': 1500,
#  'Penistone Church': 1500,
#  'Worksop Town': 1500,
#  'Redditch United': 1500,
#  'Basford United': 1500,
#  'Wakefield AFC': 1500,
#  'Viktoria Otrokovice': 1500,
#  'Liversedge': 1500,
#  'Rushall Olympic': 1500,
#  'Sheppey United': 1500,
#  'Charleroi': 1500,
#  'Telfs': 1500,
#  'Donau': 1500,
#  'Tromsdalen Uil': 1500,
#  'Hodonín': 1500,
#  'Lordswood': 1500,
#  'Kongsvinger': 1500,
#  'Notodden': 1500,
#  'Wörgl': 1500,
#  'Austria Salzburg': 1500,
#  'Asker': 1500,
#  'Brattvåg': 1500,
#  'Egersund': 1500,
#  'Kjelsås': 1500,
#  'Chlumec nad Cidlinou': 1500,
#  'Alvechurch': 1500,
#  'Rosenborg II': 1500,
#  'Øygarden': 1500,
#  'Vålerenga II': 1500,
#  'Arendal': 1500,
#  '1980 Wien': 1500,
#  'Levanger': 1500,
#  'Skeid': 1500,
#  'Gleisdorf 09': 1500,
#  'Slovan Rosice': 1500,
#  'Mannswörth': 1500,
#  'Lillestrom': 1500,
#  'Völs': 1500,
#  'Union Perg': 1500,
#  'Brumov': 1500,
#  'Bospor Bohumín': 1500,
#  'Stjørdals-Blink': 1500,
#  'Elektra': 1500,
#  'Uničov': 1500,
#  'Phönix Lübeck': 1500,
#  'Rochester United': 1500,
#  'Cumbernauld Colts': 1500,
#  'Schwaz': 1500,
#  'Alta': 1500,
#  'hodd': 1500,
#  'Floro': 1500,
#  'Kvik Halden': 1500,
#  'Ercsi Kinizsi': 1500,
#  'Scheiblingkirchen': 1500,
#  'Bærum': 1500,
#  'Kematen': 1500,
#  'Fehérvár FC': 1500,
#  'Union Bremen': 1500,
#  'Voitsberg': 1500,
#  'Bischofshofen': 1500,
#  'St. Anna': 1500,
#  'Znojmo': 1500,
#  'Vsetín': 1500,
#  'Eckernförder SV': 1500,
#  'Chatham Town': 1500,
#  'Sparta Kutná Hora': 1500,
#  'Sokol Živanice': 1500,
#  'Hlučín': 1500,
#  'Benešov': 1500,
#  'Hranice': 1500,
#  'Spartans': 1500,
#  'Kalsdorf': 1500,
#  'Hertha': 1500,
#  'Chayka': 1500,
#  'Carl Zeiss Jena': 1500,
#  'FC UFA': 1500,
#  'Malmo FF': 1500,
#  'Fram': 1500,
#  'Westfalia Kinderhaus': 1500,
#  'Eintracht Norderstedt': 1500,
#  'Spartak Moscow 2': 1500,
#  'Birkirkara': 1500,
#  'Bürmoos': 1500,
#  'Start Brno': 1500,
#  'Šumperk': 1500,
#  'OH Leuven': 1500,
#  'Ludogorets': 1500,
#  'Orenburg': 1500,
#  'Weiz': 1500,
#  'Albert Quévy-Mons': 1500,
#  'Náchod': 1500,
#  'Wels': 1500,
#  'Lebring': 1500,
#  'Bystřice nad Pernštejnem': 1500,
#  'SV Lafnitz': 1500,
#  'Donau Linz': 1500,
#  'Draxler Mooskirchen': 1500,
#  'TuS Heiligenkreuz': 1500,
#  'Neusiedl': 1500,
#  'Pinzgau Saalfelden': 1500,
#  'Bergheim': 1500,
#  'Grödig': 1500,
#  'Sheriff Tiraspol': 1500,
#  'Radomlje': 1500,
#  'Hamrun Spartans': 1500,
#  'FC Wurzburger Kickers': 1500,
#  'Dikkelvenne': 1500,
#  'K. Kontich': 1500,
#  'Zepperen-Brustem': 1500,
#  'Motorlet Praha': 1500,
#  'Tatran Všechovice': 1500,
#  'Čáslav': 1500,
#  'Žďár nad Sázavou': 1500,
#  'Eugendorf': 1500,
#  'Slavoj Trebišov': 1500,
#  'Portstewart': 1500,
#  'Lask Juniors Linz': 1500,
#  'Dukla Praha': 1500,
#  'Baltika': 1500,
#  'NK Osijek': 1500,
#  'Sereď': 1500,
#  'Žilina': 1500,
#  'Spartak Trnava': 1500,
#  'Blau-Weiß Feldkirch': 1500,
#  'Blau-Weiß 90 Berlin': 1500,
#  'FC Frankfurt': 1500,
#  'GAZ Metan Medias': 1500,
#  'Aluminij': 1500,
#  'Schwarz-Weiß Bregenz': 1500,
#  'BK Hacken': 1500,
#  'Mjallby AIF': 1500,
#  'Djurgardens IF': 1500,
#  'Cheadle Town': 1500,
#  'Tempo Overijse': 1500,
#  'Veles': 1500,
#  'Atherstone Town': 1500,
#  'AFC Darwen': 1500,
#  'Meridian': 1500,
#  'Liptovský Mikuláš': 1500,
#  'Pinkafeld': 1500,
#  'CSKA Sofia': 1500,
#  'Admira Wacker': 1500,
#  'CFR 1907 Cluj': 1500,
#  'Slavia Sofia': 1500,
#  'Berg en Dal': 1500,
#  'Ried II': 1500,
#  'Pohronie': 1500,
#  'TSC Backa Topola': 1500,
#  'Mura': 1500,
#  'St. Valentin': 1500,
#  'Deutz': 1500,
#  'AIK Stockholm': 1500,
#  'Legia Warszawa': 1500,
#  'SV Kapfenberg': 1500,
#  'Fakel Voronezh': 1500,
#  'PFC Sochi': 1500,
#  'Olimpija Ljubljana': 1500,
#  'Einheit Zepernick': 1500,
#  'Ludwigsfelde': 1500,
#  'Ilz': 1500,
#  'Thalgau': 1500,
#  'Gzira United': 1500,
#  'Leobendorf': 1500,
#  'Mladost Lucani': 1500,
#  'Hammarby FF': 1500,
#  'Lokomotiv Plovdiv': 1500,
#  'FK Spartak Zdrepceva KRV': 1500,
#  'Ružomberok': 1500,
#  'Humenné': 1500,
#  'Sparta Praha': 1500,
#  'Slovácko': 1500,
#  'Akron': 1500,
#  'MSV Duisburg': 1500,
#  'FC BW Linz': 1500,
#  'Harelbeke': 1500,
#  'FC Winterthur': 1500,
#  'Folgore': 1500,
#  'Rapid Vienna': 1500,
#  'HB Torshavn': 1500,
#  'East Kilbride': 1500,
#  'Tasmania Berlin': 1500,
#  'Vrchovina': 1500,
#  'Dorados': 1500,
#  'Keçiörengücü': 1500,
#  'Metalac GM': 1500,
#  'FC Clinceni': 1500,
#  'Volgar Astrakhan': 1500,
#  'Varbergs BoIS FC': 1500,
#  'Raków Częstochowa': 1500,
#  'IFK Goteborg': 1500,
#  'Zorya Luhansk': 1500,
#  'Cracovia Krakow': 1500,
#  'Tsarsko Selo': 1500,
#  'CSKA 1948': 1500,
#  'Pampow': 1500,
#  'Lokomotiv Moscow': 1500,
#  'FC Schalke 04': 1500,
#  'Vojvodina': 1500,
#  'SC Wiener Neustadt': 1500,
#  'Wacker Cottbus-Ströbitz': 1500,
#  'Meerbusch': 1500,
#  'Hooikt': 1500,
#  'Dessel Sport': 1500,
#  'Oudenaarde': 1500,
#  'HNK Rijeka': 1500,
#  'Heist': 1500,
#  'East Fife': 1500,
#  'Clachnacuddin': 1500,
#  'Jahn Zeiskam': 1500,
#  'Blau-Weiß Zorbau': 1500,
#  'Rot-Weiß Walldorf': 1500,
#  'Sileks': 1500,
#  'Proleter Novi SAD': 1500,
#  'Dinamo Zagreb': 1500,
#  "BAK '07": 1500,
#  'Rubin': 1500,
#  'Hobro': 1500,
#  'IFK Norrkoping': 1500,
#  'FC Copenhagen': 1500,
#  'FC Rostov': 1500,
#  'Polet': 1500,
#  'Shkendija': 1500,
#  'Petershagen-Eggersdorf': 1500,
#  'Schruns': 1500,
#  'Union Vöcklamarkt': 1500,
#  'Chrudim': 1500,
#  'Uta Arad': 1500,
#  'BFC Dynamo': 1500,
#  'Arda Kardzhali': 1500,
#  'Montana': 1500,
#  'SKU Amstetten': 1500,
#  'Inhulets': 1500,
#  'Meiningen': 1500,
#  'Zaglebie Lubin': 1500,
#  'Lausanne': 1500,
#  'Anderlecht': 1500,
#  'FC Zurich': 1500,
#  'FC Liefering': 1500,
#  'Grasshoppers': 1500,
#  'Piast Gliwice': 1500,
#  'Sturm Graz': 1500,
#  'FK Neftekhimik': 1500,
#  'Grazer AK': 1500,
#  'Rapid Wien II': 1500,
#  'Beroe': 1500,
#  'Westhoek': 1500,
#  'Camon': 1500,
#  'Red Bull Salzburg': 1500,
#  'Sochaux': 1500,
#  'Germania Halberstadt': 1500,
#  'Sturm Graz II': 1500,
#  'Luckenwalde': 1500,
#  'Prishtina': 1500,
#  'Whitton United': 1500,
#  'Runcorn Town': 1500,
#  'Punjab United': 1500,
#  'Stafford Rangers': 1500,
#  'Uherský Brod': 1500,
#  'Folkestone Invicta': 1500,
#  'Anif': 1500,
#  'Colliers Wood United': 1500,
#  'Wythenshawe Town': 1500,
#  'Ginsheim': 1500,
#  'Kickers Emden': 1500,
#  'Pfeddersheim': 1500,
#  'Krefeld-Fischeln': 1500,
#  'Bersenbrück': 1500,
#  'Porz': 1500,
#  'Lörrach-Brombach': 1500,
#  'Skegness Town': 1500,
#  'Civil Service Strollers': 1500,
#  'Brná': 1500,
#  'Clydebank': 1500,
#  'St Helens Town': 1500,
#  'Kelty Hearts': 1500,
#  'Kazincbarcikai': 1500,
#  'Glentoran': 1500,
#  'Budapest Honved': 1500,
#  'Buducnost Podgorica': 1500,
#  'Apollon Limassol': 1500,
#  'CS Universitatea Craiova': 1500,
#  'Quierschied': 1500,
#  'Vorskla Poltava': 1500,
#  'Raith Rovers': 1500,
#  'Sibenik': 1500,
#  'Khimki': 1500,
#  'Leon': 1500,
#  'Mezokovesd-zsory': 1500,
#  'MTK Budapest': 1500,
#  'Alianza Lima': 1500,
#  'Dečić': 1500,
#  'Tekstilshchik': 1500,
#  'Bravo': 1500,
#  'Minai': 1500,
#  'Stadl-Paura': 1500,
#  'Wacker Innsbruck': 1500,
#  'Levski Sofia': 1500,
#  'Cherno More Varna': 1500,
#  'Plzen': 1500,
#  'Hanácká': 1500,
#  'Pardubice': 1500,
#  'Zlin': 1500,
#  'Sigma Olomouc': 1500,
#  'Teplice': 1500,
#  'Stripfing': 1500,
#  'Šamorín': 1500,
#  'Artis': 1500,
#  'Hradec Králové': 1500,
#  'Púchov': 1500,
#  'Wisla Krakow': 1500,
#  'Slovan Liberec': 1500,
#  'Karviná': 1500,
#  'AC Horsens': 1500,
#  'Optik Rathenow': 1500,
#  'SC Paderborn 07': 1500,
#  'Dumbarton': 1500,
#  'Dynamo Dresden': 1500,
#  'Aalborg': 1500,
#  'Aarhus': 1500,
#  'Jong Utrecht': 1500,
#  'Hannover 96 II': 1500,
#  'Union Fürstenwalde': 1500,
#  'FC Grimma': 1500,
#  'Montrose': 1500,
#  'Rostocker FC': 1500,
#  'Svelta Melsele': 1500,
#  'Forfar Athletic': 1500,
#  'SV Wehen': 1500,
#  'FC ST. Gallen': 1500,
#  'Hannover 96': 1500,
#  'Anker Wismar': 1500,
#  'Blankenburger FV': 1500,
#  'Dudenhofen': 1500,
#  'Zandhovense': 1500,
#  'Voorwaarts Zwevezele': 1500,
#  'Krasnodar 2': 1500,
#  'Zulte Waregem': 1500,
#  'FC Heidenheim': 1500,
#  'FC Nurnberg': 1500,
#  'SKN ST. Polten': 1500,
#  'Matrei': 1500,
#  'Petrocub': 1500,
#  'Austria Vienna': 1500,
#  'Jahn Regensburg': 1500,
#  'Wolfsberger AC': 1500,
#  'Standard Liege': 1500,
#  'Club Brugge KV': 1500,
#  'NK Slaven Belupo': 1500,
#  'Dunkerque': 1500,
#  'Celje': 1500,
#  'Maribor': 1500,
#  'VfB Bottrop 1900': 1500,
#  'Attendorn': 1500,
#  'Cancún': 1500,
#  'Frechen': 1500,
#  'FC Basel 1893': 1500,
#  'BW Lohne': 1500,
#  'Botev Plovdiv': 1500,
#  'Galatasaray': 1500,
#  'Krasnodar': 1500,
#  'Novi Pazar': 1500,
#  'Tabor Sežana': 1500,
#  'New Mills': 1500,
#  'FC Fredericia': 1500,
#  'Degerfors IF': 1500,
#  'FC Mariupol': 1500,
#  'Mosta': 1500,
#  'Bedford Town': 1500,
#  'Atherton Collieries': 1500,
#  'Brondby': 1500,
#  'BSC Young Boys': 1500,
#  'Köttmannsdorf': 1500,
#  'FK Crvena Zvezda': 1500,
#  'Röthis': 1500,
#  'Allerheiligen': 1500,
#  'Volyn': 1500,
#  'Larne': 1500,
#  'Rotor Volgograd': 1500,
#  'WSG Wattens': 1500,
#  'Radnicki NIS': 1500,
#  'Helsingborg': 1500,
#  'Vejle': 1500,
#  'Ahrobiznes Volochysk': 1500,
#  'Spartak Moscow': 1500,
#  'Pogon Szczecin': 1500,
#  'Næsby': 1500,
#  'HNK Hajduk Split': 1500,
#  'Admira Dornbirn': 1500,
#  'Necaxa': 1500,
#  'Bekescsaba 1912': 1500,
#  'FK Vozdovac': 1500,
#  'Zemplín Michalovce': 1500,
#  'Eichstätt': 1500,
#  'Monterrey': 1500,
#  'Ware': 1500,
#  'Heimstetten': 1500,
#  'Plauen': 1500,
#  'Tennis Borussia': 1500,
#  'Sementina': 1500,
#  'Union Nettetal': 1500,
#  'CSKA 1948 Sofia II': 1500,
#  'Langenfeld': 1500,
#  'Viktoria Žižkov': 1500,
#  'Hamburger SV': 1500,
#  'PEC Zwolle': 1500,
#  'Vitesse': 1500,
#  'Beerschot VA': 1500,
#  'KV Mechelen': 1500,
#  'FCSB': 1500,
#  'FK Partizan': 1500,
#  'Linfield': 1500,
#  'Fola Esch': 1500,
#  'Ferencvarosi TC': 1500,
#  'AS Eupen': 1500,
#  'Eintracht Braunschweig': 1500,
#  'Krylya Sovetov': 1500,
#  'Ska-khabarovsk': 1500,
#  'Sozopol': 1500,
#  'Auxerre': 1500,
#  'Rudar Velenje': 1500,
#  'Třinec': 1500,
#  'Bohemians 1905': 1500,
#  'Stal Mielec': 1500,
#  'St. Truiden': 1500,
#  'Hansa Rostock': 1500,
#  'St. Johann in Tirol': 1500,
#  'HNK Gorica': 1500,
#  'Lech Poznan': 1500,
#  'Oberwart / Rotenturm': 1500,
#  'České Budějovice': 1500,
#  'Paks': 1500,
#  'FC Luzern': 1500,
#  'Olympiakos Piraeus': 1500,
#  'Ajaccio': 1500,
#  'Rapperswil': 1500,
#  'VfB Oldenburg': 1500,
#  'Bahlinger SC': 1500,
#  'FK Zlatibor': 1500,
#  'TSV Hartberg': 1500,
#  'FC St. Pauli': 1500,
#  'BSG Chemie Leipzig': 1500,
#  'Wiener Viktoria': 1500,
#  'Sparta Petegem': 1500,
#  'Slovan Bratislava': 1500,
#  'ÖTSU Hallein': 1500,
#  'Ansbach': 1500,
#  'Lennestadt': 1500,
#  'TuS Marienborn': 1500,
#  'SGI': 1500,
#  'Burdur MAKÜ Spor': 1500,
#  'SR Neustadt': 1500,
#  'Blau-Weiß Köln': 1500,
#  'Cheshunt': 1500,
#  'Harrogate Town': 1500,
#  'Torpedo Moskva': 1500,
#  'Dnipro-1': 1500,
#  'Herstedøster': 1500,
#  'NK Domzale': 1500,
#  'Arsenal Tula': 1500,
#  'Puskas Academy': 1500,
#  'Yverdon Sport': 1500,
#  'Kolding IF': 1500,
#  'Draßburg': 1500,
#  'Melksham Town': 1500,
#  'Goole': 1500,
#  'Hemsworth MW': 1500,
#  'Keynsham Town': 1500,
#  'Kuchl': 1500,
#  'Dortelweil': 1500,
#  'Ujpest': 1500,
#  'Lyngby': 1500,
#  'Dinamo Moscow': 1500,
#  'Atletico Nacional': 1500,
#  'VfL Osnabruck': 1500,
#  'Lviv': 1500,
#  'Nieciecza': 1500,
#  'RKSV Nuenen': 1500,
#  'FC WIL 1900': 1500,
#  'Heracles': 1500,
#  'Nizhny Novgorod': 1500,
#  'Holstein Kiel': 1500,
#  'Valenciennes': 1500,
#  'Le Havre': 1500,
#  'Ried': 1500,
#  'Dijon': 1500,
#  'Gifhorn': 1500,
#  'Staines Town': 1500,
#  'Cleethorpes Town': 1500,
#  'Zbuzany': 1500,
#  'Vyškov': 1500,
#  'Pontefract Collieries': 1500,
#  'KAMAZ': 1500,
#  'Elgin City': 1500,
#  'Uzhhorod': 1500,
#  'Vlašim': 1500,
#  'Silvolde': 1500,
#  'Eendracht Termien': 1500,
#  'Haringey Borough': 1500,
#  'Carshalton Athletic': 1500,
#  'Verl': 1500,
#  'Dornbirn': 1500,
#  'United of Manchester': 1500,
#  'Sparta Enschede': 1500,
#  'Botev Plovdiv II': 1500,
#  'Astoria Walldorf II': 1500,
#  'Sprockhovel': 1500,
#  'Dusseldorf-West': 1500,
#  'Sportfreunde Siegen': 1500,
#  'SSVg Velbert': 1500,
#  'Neckarsulmer SU': 1500,
#  'Peterborough Sports': 1500,
#  'Eilenburg': 1500,
#  'Limavady United': 1500,
#  'Nuneaton Town': 1500,
#  'Cusco': 1500,
#  'Auerbach': 1500,
#  'Altona 93': 1500,
#  'Garching': 1500,
#  'Coggeshall United': 1500,
#  'Tonbridge Angels': 1500,
#  'Dorking Wanderers': 1500,
#  'Chornomorets': 1500,
#  'Caen': 1500,
#  'FK Jablonec': 1500,
#  'FC Thun': 1500,
#  'Vizela': 1500,
#  'Karlsruher SC': 1500,
#  'FC Lugano': 1500,
#  'Senica': 1500,
#  'Wisla Plock': 1500,
#  'Livingston': 1500,
#  'Heart Of Midlothian': 1500,
#  'Guimaraes': 1500,
#  'Moreirense': 1500,
#  'Heerenveen': 1500,
#  'Feyenoord': 1500,
#  'Excelsior': 1500,
#  'Ajax': 1500,
#  'FC Magdeburg': 1500,
#  'Nice': 1500,
#  'Sportfreunde Lotte': 1500,
#  'Katwijk': 1500,
#  'Radnik Surdulica': 1500,
#  'ACS Sirineasa': 1500,
#  'Arges Pitesti': 1500,
#  'Chindia Targoviste': 1500,
#  'Szolnoki MAV FC': 1500,
#  'Queen of the South': 1500,
#  'Gyori ETO FC': 1500,
#  'Debreceni VSC': 1500,
#  'Brechin': 1500,
#  'Alloa Athletic': 1500,
#  'Diosgyori VTK': 1500,
#  'Club Tijuana': 1500,
#  'Cruz Azul': 1500,
#  'Septemvri Simitli': 1500,
#  'Mannsdorf-Großenzersdorf': 1500,
#  'Opava': 1500,
#  'Zlaté Moravce': 1500,
#  'Táborsko': 1500,
#  'ŁKS Łódź': 1500,
#  'Baník Ostrava': 1500,
#  'Gornik Zabrze': 1500,
#  'Mlada Boleslav': 1500,
#  'SSV Jeddeloh': 1500,
#  'Jagiellonia': 1500,
#  'Korona Kielce': 1500,
#  'Odense': 1500,
#  'Energie Cottbus': 1500,
#  'FC Lok Stendal': 1500,
#  'St. Pauli II': 1500,
#  'GO Ahead Eagles': 1500,
#  'Schwarz-Weiß Rehden': 1500,
#  'Eintracht Celle': 1500,
#  'PSV Eindhoven': 1500,
#  'Plymouth Parkway': 1500,
#  'Kidsgrove Athletic': 1500,
#  'Clyde': 1500,
#  'Spennymoor Town': 1500,
#  'AZ Alkmaar': 1500,
#  'SCR Altach': 1500,
#  'Hitchin Town': 1500,
#  'Estac Troyes': 1500,
#  'Lask Linz': 1500,
#  'Servette FC': 1500,
#  'Dunajska Streda': 1500,
#  'Pelikaan-S': 1500,
#  'Siegendorf': 1500,
#  'Quevilly': 1500,
#  'SV Horst-Emscher': 1500,
#  'Germania Leer': 1500,
#  'CFC Hertha': 1500,
#  'Westfalia Herne': 1500,
#  'Schonnebeck': 1500,
#  'Gonsenheim': 1500,
#  'Resovia Rzeszów': 1500,
#  'Torpedo Vladimir': 1500,
#  'Rukh Vynnyky': 1500,
#  'Aris Thessalonikis': 1500,
#  'Envigado': 1500,
#  'Monarcas': 1500,
#  'Enisey': 1500,
#  'FC Kaiserslautern': 1500,
#  'Marseille': 1500,
#  'Tus Dassendorf': 1500,
#  'Werder Bremen': 1500,
#  'Clitheroe': 1500,
#  'Sloboda Tuzla': 1500,
#  'Bastia': 1500,
#  'Rio Grande Valley': 1500,
#  'Triglav': 1500,
#  'Chadderton': 1500,
#  'Mjøndalen II': 1500,
#  'Grays Athletic': 1500,
#  'AEL': 1500,
#  'Matlock Town': 1500,
#  'Partick': 1500,
#  'Esbjerg': 1500,
#  'Patriotas': 1500,
#  'Santos Laguna': 1500,
#  'Türkgücü-Ataspor': 1500,
#  'CSKA Moscow': 1500,
#  'Barking': 1500,
#  'Frome Town': 1500,
#  'Broxburn Athletic': 1500,
#  'Witton Albion': 1500,
#  'St. Pölten II': 1500,
#  '1874 Northwich': 1500,
#  'Harborough Town': 1500,
#  'Hebburn Town': 1500,
#  'Havelse': 1500,
#  '1880 Wasserburg': 1500,
#  'Meerssen': 1500,
#  'Donaustauf': 1500,
#  'Frankonia Wernsdorf': 1500,
#  'Heinenoord': 1500,
#  'SGK Heidelberg': 1500,
#  'Schifferstadt': 1500,
#  'Wolfurt': 1500,
#  'Raufoss II': 1500,
#  'Eastbourne Borough': 1500,
#  'Traiskirchen': 1500,
#  'SV Sandhausen': 1500,
#  'Santa Clara': 1500,
#  'Farense': 1500,
#  'Lechia Gdansk': 1500,
#  'Arka Gdynia': 1500,
#  'Kortrijk': 1500,
#  'Botev Vratsa': 1500,
#  'VfL Wolfsburg': 1500,
#  'Accrington ST': 1500,
#  'Union St. Gilloise': 1500,
#  "Quick '20": 1500,
#  'Rogaška': 1500,
#  'Austria Klagenfurt': 1500,
#  'Hollenbach': 1500,
#  'Dundee': 1500,
#  'Flora Tallinn': 1500,
#  'Hsc 21': 1500,
#  'Union St. Florian': 1500,
#  'FC Eindhoven': 1500,
#  'Venray': 1500,
#  'Walton Casuals': 1500,
#  'Varnsdorf': 1500,
#  'Mornar': 1500,
#  'Tikveš': 1500,
#  'NŠ Drava': 1500,
#  'Pécsi MFC': 1500,
#  'Tállya': 1500,
#  'Veres Rivne': 1500,
#  'St. Margarethen': 1500,
#  'Abtswind': 1500,
#  'Alfter': 1500,
#  'VfL Halle': 1500,
#  'Estrela': 1500,
#  'Staaken': 1500,
#  'Widnau': 1500,
#  'Delbrücker SC': 1500,
#  'Toten': 1500,
#  'Kolos Kovalivka': 1500,
#  'Partizán Bardejov': 1500,
#  'Benfica': 1500,
#  'Lens': 1500,
#  'Genk': 1500,
#  'QPR': 1500,
#  'Monori Se': 1500,
#  'Atletico San Luis': 1500,
#  'Toluca': 1500,
#  'GIL Vicente': 1500,
#  'Santa Fe': 1500,
#  'Oborishte': 1500,
#  'Jastrzębie': 1500,
#  'Zaglebie Sosnowiec': 1500,
#  'FC Augsburg': 1500,
#  'Puszcza Niepołomice': 1500,
#  'MSV Neuruppin': 1500,
#  'Sheffield Wednesday': 1500,
#  'FC Sion': 1500,
#  'Dinamo Tbilisi': 1500,
#  'Laval': 1500,
#  'Maccabi Haifa': 1500,
#  'Teuta Durrës': 1500,
#  'Cukaricki': 1500,
#  'Falkensee-Finkenkrug': 1500,
#  'GAP Connah S Quay FC': 1500,
#  'Campion': 1500,
#  'Schwachhausen': 1500,
#  'AFC Emley': 1500,
#  'Fortuna Dusseldorf': 1500,
#  'Biggleswade': 1500,
#  'Aberdeen': 1500,
#  'FSV Zwickau': 1500,
#  'Tigres UANL': 1500,
#  'Club America': 1500,
#  'Kisvarda FC': 1500,
#  'CF Pachuca': 1500,
#  'Sittingbourne': 1500,
#  'Csikszereda': 1500,
#  'Casa Pia': 1500,
#  'Annecy': 1500,
#  'Nosta': 1500,
#  'SCM Gloria Buzău': 1500,
#  'Khimik Dzerzhinsk': 1500,
#  'Long Melford': 1500,
#  'Ennepetal': 1500,
#  'Hünfelder SV': 1500,
#  'Zebau Bad Ischl': 1500,
#  'Stoke City': 1500,
#  'Lorient': 1500,
#  'FSV Mainz 05': 1500,
#  'SpVgg Greuther Furth': 1500,
#  'Utrecht': 1500,
#  'Varzim': 1500,
#  'SK Beveren': 1500,
#  'Universitario': 1500,
#  'Club Queretaro': 1500,
#  'Landskrona BoIS': 1500,
#  'Fortuna Koln': 1500,
#  'Internacional de Bogota': 1500,
#  'Osters IF': 1500,
#  'Shakhtar Donetsk': 1500,
#  'Wiener SC': 1500,
#  'Strasbourg': 1500,
#  'PAOK': 1500,
#  'VVV Venlo': 1500,
#  'Squires Gate': 1500,
#  'Tiverton Town': 1500,
#  'Ossett United': 1500,
#  'Cray Valley PM': 1500,
#  'Trafford': 1500,
#  'Welwyn Garden City': 1500,
#  'Bognor Regis Town': 1500,
#  'Wimborne Town': 1500,
#  'Badshot Lea': 1500,
#  'Boldmere St. Michaels': 1500,
#  'Velké Meziříčí': 1500,
#  'Tamworth': 1500,
#  'III. Kerületi TUE': 1500,
#  'Market Drayton Town': 1500,
#  'Horley Town': 1500,
#  'Beltinci': 1500,
#  'Sirens': 1500,
#  'Atletik Kuklen': 1500,
#  'Tiszaújváros': 1500,
#  'Ballyclare Comrades': 1500,
#  'Auchinleck Talbot': 1500,
#  'Linlithgow Rose': 1500,
#  'Cinderford Town': 1500,
#  'Corby Town': 1500,
#  'Didcot Town': 1500,
#  'Sutton Coldfield Town': 1500,
#  'Padiham': 1500,
#  'Stern': 1500,
#  'Thackley': 1500,
#  'Wolfenbuttel': 1500,
#  'Diefflen': 1500,
#  'Mülheim-Kärlich': 1500,
#  'SVE Wald-Michelbach': 1500,
#  'Vilzing': 1500,
#  'Eisbachtal': 1500,
#  'Wisła Puławy': 1500,
#  'North Ferriby': 1500,
#  'Beckum': 1500,
#  ...}

# %% [markdown]
# #### Función para hacer un reinicio de los pts de los equipos
#
# * Cada nueva temporada tenemos que hacer un reinicio parcial de los pts obtenidos, esto es debido a que los equipos se refuerzan o desarman, cambian de DT, compran y venden jugadores, personal, etc.
#
# * Actualmente nos quedamos con el 0.33% de los puntos obtenidos en la campaña.

# %%
def reboot_elo_new_seasson(elo_dictionary):

  for team, elo in elo_dictionary.items():
    #print(team, elo)
    #elo_dictionary[team] = (elo * 0.75) + (1500 * 0.25)
    elo_dictionary[team] = (elo * 0.67) + (1500 * 0.33)

# %% [markdown]
# #### Función para crear la tabla ELO hasta el último partido registrado

# %%
# HFA = ventaja de local (Home Field Advantage)
# K = Es un valor dinámico (respecto al torneo) para darle variedad a la puntuación
K, HFA = 20, 53
test_reboot_elo_ranking = True

# Listas temporales para guardar el estado ANTES del partido
elo_home_pre = []
elo_away_pre = []

current_year = int(AVAILABLE_SEASSONS[0])

# Recorremos todos los partidos
for index, row in df.iterrows():

  if row['season'] != current_year and test_reboot_elo_ranking:
    display(f"Last year: {current_year} // Current year {row['season']}")
    current_year = row['season']
    reboot_elo_new_seasson(elo_dictionary)

  home = row['home_team']
  away = row['away_team']
  goals_h = row['home_goals']
  goals_a = row['away_goals']

  # 1. Leer el elo actual de los equipos
  elo_current_h = elo_dictionary[home]
  elo_current_a = elo_dictionary[away]


  if index == 0:
    display(home)
    display(away)
    display(f"H: {elo_current_h} // A: {elo_current_a}")

  # 2. Guardarlo para el modelo predictivo
  elo_home_pre.append(elo_current_h)
  elo_away_pre.append(elo_current_a)

  # 3. Calcular la probabilidad con la fórmula de elo
  # Agregamos +100 al local para simular la ventaja de jugar en casa (Home Field Advantage)
  E_home = 1 / (1 + 10 ** (((elo_current_a) - (elo_current_h + HFA)) / 400))
  E_away = 1 - E_home

  # 4. Determinar el resultado real
  # (1 = gana local, 0.5 = empate, 0 = gana visita)
  if goals_h > goals_a:
      S_home, S_away = 1, 0
  elif goals_h == goals_a:
      S_home, S_away = 0.5, 0.5
  else:
      S_home, S_away = 0, 1

  # 5. Multiplicar por el margen de victoria
  # Un 4-0 demuestra más superioridad que un 1-0
  # Usamos la raíz cuadrada de la diferencia para amplificar un resultado grande
  margin_goals = abs(goals_h - goals_a)
  margin_multiplier = math.sqrt(margin_goals) if margin_goals > 0 else 1.0

  # 6. Calcular los puntos ganados en el partido
  change_elo_home = K * margin_multiplier * (S_home - E_home)
  change_elo_away = K * margin_multiplier * (S_away - E_away)

  # 7. Actualizar el diccionario de los equipos con los elo
  elo_dictionary[home] = elo_current_h + change_elo_home
  elo_dictionary[away] = elo_current_a + change_elo_away

  # ¿No se debería ir actualizando el ELO respecto a cada partido?
  # 8. Añadir el elo al dataframe
  df.at[index, 'Elo_Home_Pre'] = elo_current_h
  df.at[index, 'Elo_Away_Pre'] = elo_current_a
  df.at[index, 'Elo_Diff'] = (elo_current_h - elo_current_a)
# Out:
# 'Sanna Khanh Hoa'
# 'Da Nang'
# 'H: 1500 // A: 1500'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2021'
# 'Last year: 2021 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2022'
# 'Last year: 2022 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2023'
# 'Last year: 2023 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2024'
# 'Last year: 2024 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'
# 'Last year: 2026 // Current year 2025'
# 'Last year: 2025 // Current year 2026'

# %%
df
# Out:
#        fixture_id  season                      date          home_team  \
# 0          738437    2021 2021-01-01 09:00:00+00:00    Sanna Khanh Hoa
# 1          738438    2021 2021-01-01 11:00:00+00:00         Binh Duong
# 2          738439    2021 2021-01-02 10:00:00+00:00        Ho Chi Minh
# 3          738440    2021 2021-01-02 12:30:00+00:00            Sai Gon
# 4          738441    2021 2021-01-02 15:30:00+00:00           Alondras
# ...           ...     ...                       ...                ...
# 41649     1379341    2025 2026-05-24 15:00:00+00:00     Crystal Palace
# 41650     1379345    2025 2026-05-24 15:00:00+00:00  Nottingham Forest
# 41651     1379342    2025 2026-05-24 15:00:00+00:00             Fulham
# 41652     1546577    2026 2026-05-27 17:00:00+00:00            Medeama
# 41653     1542333    2026 2026-05-29 18:00:00+00:00  Mamelodi Sundowns
#
#                away_team  home_goals  away_goals  Elo_Home_Pre  Elo_Away_Pre  \
# 0                Da Nang           2           3   1500.000000   1500.000000
# 1               Nam Dinh           2           1   1500.000000   1500.000000
# 2                 Ha Noi           2           1   1500.000000   1500.000000
# 3              Binh Dinh           1           1   1500.000000   1500.000000
# 4                 Coruxo           0           2   1500.000000   1500.000000
# ...                  ...         ...         ...           ...           ...
# 41649            Arsenal           1           2   1497.175335   1503.952054
# 41650        Bournemouth           1           1   1500.543462   1502.099691
# 41651          Newcastle           2           0   1498.169915   1501.798929
# 41652  Basake Holy Stars           2           1   1500.000000   1500.000000
# 41653         RB Leipzig           3           1   1500.000000   1500.000000
#
#        Elo_Diff
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
# ...         ...
# 41649 -6.776719
# 41650 -1.556228
# 41651 -3.629015
# 41652  0.000000
# 41653  0.000000
#
# [41654 rows x 10 columns]

# %%
#Contador para ver cuántas veces gana el visitante y cuántas veces el local
favorito_local_y_gana = 0
favorito_visita_y_gana = 0
empates_totales = 0

for index, row in df.iterrows():
    # Determinamos qué pasó en la vida real
    if row['home_goals'] > row['away_goals']:
        resultado_real = '1' # Ganó Local
    elif row['home_goals'] == row['away_goals']:
        resultado_real = 'X' # Empate
    else:
        resultado_real = '2' # Ganó Visita

    # Caso A: El Local era el favorito por ELO (Elo_Diff > 0) y cumplió ganando
    if row['Elo_Diff'] > 0 and resultado_real == '1':
        favorito_local_y_gana += 1

    # Caso B: El Visitante era el favorito por ELO (Elo_Diff < 0) y rompió la localía ganando
    elif row['Elo_Diff'] < 0 and resultado_real == '2':
        favorito_visita_y_gana += 1

    # Conteo de empates reales para el contexto general
    if resultado_real == 'X':
        empates_totales += 1

total_partidos = len(df)
pct_local = (favorito_local_y_gana / total_partidos) * 100
pct_visita = (favorito_visita_y_gana / total_partidos) * 100
pct_empates = (empates_totales / total_partidos) * 100

print(f"Veces que el Local era favorito en ELO y SÍ ganó: {favorito_local_y_gana} ({pct_local:.2f}%)")
print(f"Veces que el Visitante era favorito en ELO y SÍ ganó: {favorito_visita_y_gana} ({pct_visita:.2f}%)")
print(f"Empates reales registrados en el dataset: {empates_totales} ({pct_empates:.2f}%)")
# Out:
# Veces que el Local era favorito en ELO y SÍ ganó: 9882 (23.72%)
# Veces que el Visitante era favorito en ELO y SÍ ganó: 7592 (18.23%)
# Empates reales registrados en el dataset: 8346 (20.04%)

# %%
#Contador para ver cuántas veces gana el visitante sin ser favorito
no_favorito_visita_y_gana = 0


for index, row in df.iterrows():
    # Determinamos qué pasó en la vida real
    if row['home_goals'] > row['away_goals']:
        resultado_real = '1' # Ganó Local
    elif row['home_goals'] == row['away_goals']:
        resultado_real = 'X' # Empate
    else:
        resultado_real = '2' # Ganó Visita

    # Caso A: El Visitante no era el favorito por ELO (Elo_Diff > 0) y rompió la localía ganando
    if row['Elo_Diff'] > 0 and resultado_real == '2':
      no_favorito_visita_y_gana += 1


total_partidos = len(df)
pct_visita = (no_favorito_visita_y_gana / total_partidos) * 100

print(f"Veces que el Visitante no era favorito en ELO y SÍ ganó: {favorito_visita_y_gana} ({pct_visita:.2f}%)")
# Out:
# Veces que el Visitante no era favorito en ELO y SÍ ganó: 7592 (13.98%)

# %% [markdown]
# #### <font color=pink>Observar el ELO ranking final</font>

# %%
display(pd.Series(elo_dictionary).sort_values(ascending=False).round(2).head(30))
# Out:
# Manchester United           1514.65
# Aston Villa                 1514.30
# Mamelodi Sundowns           1512.00
# Arsenal                     1510.23
# Medeama                     1508.49
# West Ham                    1508.05
# Partizani                   1507.31
# Fulham                      1506.91
# Sunderland                  1505.99
# Tottenham                   1505.31
# Borussia Mönchengladbach    1504.64
# Eintracht Frankfurt         1502.98
# Bournemouth                 1502.39
# Brentford                   1500.63
# Paris Saint Germain         1500.33
# Francs Borains              1500.22
# Rapid Wien II               1500.22
# Metz                        1500.06
# SKRA Częstochowa            1500.04
# Twente                      1500.02
# AS Marsa                    1500.01
# The Strongest               1500.01
# Tvååker                     1500.01
# Honka                       1500.01
# Rot-Weiß Essen              1500.01
# Provincial Ovalle           1500.01
# Pors Grenland               1500.01
# FC Vaduz                    1500.01
# Kazincbarcikai              1500.01
# Levanger                    1500.01
# dtype: float64

# %%
len(df)
# Out:
# 41654

# %% [markdown]
# ### **Standard Scaler**

# %%
df.head(2)
# Out:
#    fixture_id  season                      date        home_team away_team  \
# 0      738437    2021 2021-01-01 09:00:00+00:00  Sanna Khanh Hoa   Da Nang
# 1      738438    2021 2021-01-01 11:00:00+00:00       Binh Duong  Nam Dinh
#
#    home_goals  away_goals  Elo_Home_Pre  Elo_Away_Pre  Elo_Diff
# 0           2           3        1500.0        1500.0       0.0
# 1           2           1        1500.0        1500.0       0.0

# %%
# El número de partidos que tienen exactamente 1500
# estos partidos son los que iniciaron nuestra puntuación elo
df_test = df[df['Elo_Home_Pre'] == 1500].copy()
len(df_test)
# Out:
# 6222

# %%
# Eliminamos los primeros partidos que ayudaron a inicializar
# Son los que exactamente tienen 1,500 pts
df_train = df[df['Elo_Home_Pre'] != 1500].copy()
len(df_train)
# Out:
# 35432

# %%
SCALER = StandardScaler()

X_local = df_train[['Elo_Home_Pre', 'Elo_Away_Pre']]
y_local = df_train['home_goals']

X_away = df_train[['Elo_Away_Pre', 'Elo_Home_Pre']]
y_away = df_train['away_goals']

X_local_scaled = SCALER.fit_transform(X_local)
X_away_scaled = SCALER.fit_transform(X_away)

# %%
display(X_local_scaled)
display(X_away_scaled)
# Out:
# array([[-0.61232721, -0.25054011],
#        [ 0.0891373 , -0.74093151],
#        [-0.2089312 , -0.65273545],
#        ...,
#        [-0.23913397, -0.1611104 ],
#        [-0.33723133, -0.17392039],
#        [-0.26159496, -0.25054011]])
# array([[-0.25054011, -0.61232721],
#        [-0.74093151,  0.0891373 ],
#        [-0.65273545, -0.2089312 ],
#        ...,
#        [-0.1611104 , -0.23913397],
#        [-0.17392039, -0.33723133],
#        [-0.25054011, -0.26159496]])

# %%
elo_original = df[['Elo_Home_Pre']]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Gráfico 1: Antes del escalado
sns.histplot(elo_original, kde=True, color='skyblue', ax=ax1)
ax1.set_title('Distribución Original (Elo)')
ax1.set_xlabel('Puntos de Elo')

# Gráfico 2: Después del escalado
sns.histplot(X_local_scaled, kde=True, color='olive', ax=ax2)
ax2.set_title('Distribución con StandardScaler')
ax2.set_xlabel('Valor Estandarizado (Z-Score)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🏁 <font color=#258FE8>**Baseline**</font> (Avance 3)

# %%
df_train.head(2)
# Out:
#    fixture_id  season                      date   home_team  \
# 5      738442    2021 2021-01-03 09:00:00+00:00    Nam Dinh
# 6      738443    2021 2021-01-03 11:00:00+00:00  Binh Duong
#
#            away_team  home_goals  away_goals  Elo_Home_Pre  Elo_Away_Pre  \
# 5  Hoang Anh Gia Lai           1           1   1491.513739   1500.000000
# 6    Sanna Khanh Hoa           0           0   1508.486261   1488.486261
#
#     Elo_Diff
# 5  -8.486261
# 6  20.000000

# %% [markdown]
# ### Train

# %%
# 1. PREPARACIÓN DE DATOS
# Features: Usamos el Elo de ambos para capturar la diferencia de nivel
X_local = df_train[['Elo_Home_Pre', 'Elo_Away_Pre']]
y_local = df_train['home_goals']

# Para el visitante invertimos el orden lógico para el modelo
X_visita = df_train[['Elo_Away_Pre', 'Elo_Home_Pre']]
y_visita = df_train['away_goals']

# 2. ENTRENAMIENTO DEL MODELO POISSON
modelo_local = make_pipeline(StandardScaler(), PoissonRegressor())
modelo_visita = make_pipeline(StandardScaler(), PoissonRegressor())

modelo_local.fit(X_local, y_local)
modelo_visita.fit(X_visita, y_visita)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('poissonregressor', PoissonRegressor())])

# %% [markdown]
# ### Inference

# %%
# ---------------------------------------------------------
# PREDICCIÓN QUINIELA
# Equipo A vs Equipo B
# ---------------------------------------------------------
def inference_vol1(name_local, name_away):

  print(f"{name_local} vs {name_away}\n")

  elo_equipo_A, elo_equipo_B = elo_dictionary[name_local], elo_dictionary[name_away] # LOCAL / VISITANTE

  elo_diff = elo_equipo_A - elo_equipo_B

  # A. Predecir los Goles Esperados (Lambda)
  lambda_local = modelo_local.predict([[elo_equipo_A, elo_equipo_B]])[0]
  lambda_visita = modelo_visita.predict([[elo_equipo_B, elo_equipo_A]])[0]

  print(f"Goles esperados Local: {lambda_local:.2f}")
  print(f"Goles esperados Visita: {lambda_visita:.2f}\n")

  # B. Simular la Matriz de Marcadores usando la distribución de Poisson
  max_goles = 5 # Marcadores más allá de 5 goles son estadísticamente raros
  prob_victoria_local = 0
  prob_empate = 0
  prob_victoria_visita = 0

  for goles_L in range(max_goles + 1):
      for goles_V in range(max_goles + 1):
          # La probabilidad de un marcador exacto (ej. 2-1) es la multiplicación de las probabilidades independientes de los goles de cada equipo
          prob_marcador = poisson.pmf(goles_L, lambda_local) * poisson.pmf(goles_V, lambda_visita)

          # Clasificar la probabilidad en la cubeta correcta para la quiniela
          if goles_L > goles_V:
              prob_victoria_local += prob_marcador
          elif goles_L == goles_V:
              prob_empate += prob_marcador
          else:
              prob_victoria_visita += prob_marcador


  # AJUSTE MANUAL DE EMPATES (Heurística tipo Dixon-Coles)

  # 1. Definir cuándo aplica el ajuste (ej. si la diferencia de Elo es menor a 200 puntos)
  umbral_elo_parejo = 200
  empuje_empate = 0.04 # Le vamos a sumar 4% al empate

  if abs(elo_diff) < umbral_elo_parejo:
      # Aumentamos el empate
      prob_empate += empuje_empate

      # Calculamos cuánto espacio queda para repartir entre Local y Visita
      espacio_restante = 1.0 - prob_empate

      # ¿Cuánto sumaban las victorias originales?
      suma_victorias_original = prob_victoria_local + prob_victoria_visita

      # Recalculamos las victorias proporcionalmente al espacio que queda
      prob_victoria_local = (prob_victoria_local / suma_victorias_original) * espacio_restante
      prob_victoria_visita = (prob_victoria_visita / suma_victorias_original) * espacio_restante

  # ----------------------------------------------------------------

  print("--- PRONÓSTICO PARA LA QUINIELA ---")
  print(f"Diff {elo_diff}")
  print(f"Probabilidad Local (1): {prob_victoria_local * 100:.1f}%")
  print(f"Probabilidad Empate (X): {prob_empate * 100:.1f}%")
  print(f"Probabilidad Visita (2): {prob_victoria_visita * 100:.1f}%\n")
  #----------------------------------------------------------------
  # Para poder pasar al cálculo de accuracy, guardamos la decisión del modelo:
  # REGLA 1: SI EL VISITANTE TIENE MEJOR ELO Y SU PROBABILIDAD SUPERA EL UMBRAL DEFINIDO
  # Si el visitante es superior en ELO y la diferencia de probabilidades es menor a 0.22,
  # asumimos que tiene los argumentos deportivos para romper la localía.
  dif_prob = prob_victoria_local - prob_victoria_visita

  #Regla 1, empate si la diferencia de probabilidad es muy corta entre 7.21% y 14% que es el mínimo de diferencia del dataset
  if 0.0721 <= dif_prob <= 0.14:
    resultado_predicho = "X"

  #Regla 2, cuando ELO del visitante es mayor al local y la diferencia de probabilidades es menor a 22%
  elif elo_equipo_B > elo_equipo_A and dif_prob < 0.22:
      resultado_predicho = "2" # Predicción formal: Victoria Visitante

  #Regla 3, cuando la probabilidad de victoria es mayor para el visitante
  elif prob_victoria_visita > prob_victoria_local:
      resultado_predicho = "2" # Predicción formal: Victoria Visitante

  # REGLA 4: CONDICIÓN COMPLEMENTARIA PARA EL LOCAL
  # Si no se cumple lo anterior, pero el local mantiene la ventaja probabilística tradicional,
  elif prob_victoria_local > prob_victoria_visita:
      resultado_predicho = "1" # Predicción formal: Victoria Local

  # REGLA 5: CASOS DE EXCEPCIÓN por defecto
  else:
      resultado_predicho = "1"

  return resultado_predicho

# %% [markdown]
# ### Testing

# %%
print(pd.Series(elo_dictionary).sort_values(ascending=False).round(2).head(25))
# Out:
# Manchester United           1514.65
# Aston Villa                 1514.30
# Mamelodi Sundowns           1512.00
# Arsenal                     1510.23
# Medeama                     1508.49
# West Ham                    1508.05
# Partizani                   1507.31
# Fulham                      1506.91
# Sunderland                  1505.99
# Tottenham                   1505.31
# Borussia Mönchengladbach    1504.64
# Eintracht Frankfurt         1502.98
# Bournemouth                 1502.39
# Brentford                   1500.63
# Paris Saint Germain         1500.33
# Francs Borains              1500.22
# Rapid Wien II               1500.22
# Metz                        1500.06
# SKRA Częstochowa            1500.04
# Twente                      1500.02
# AS Marsa                    1500.01
# The Strongest               1500.01
# Tvååker                     1500.01
# Honka                       1500.01
# Rot-Weiß Essen              1500.01
# dtype: float64

# %%
print(pd.Series(elo_dictionary).sort_values(ascending=False).round(2).tail(25))
# Out:
# Bologna              1499.95
# SC Braga             1499.79
# Leobendorf           1499.78
# Southampton          1499.78
# SV Sandhausen        1499.77
# Seraing United       1499.73
# Bayern München       1499.71
# Wolves               1499.53
# Atletico Madrid      1499.43
# Nottingham Forest    1499.38
# Liverpool            1498.03
# Burnley              1497.54
# RW Frankfurt         1497.24
# Manchester City      1495.39
# Spelle-Venhaus       1495.36
# SC Freiburg          1494.32
# Chelsea              1494.10
# Newcastle            1493.07
# Everton              1493.05
# Vora                 1492.69
# Basake Holy Stars    1491.51
# Leeds                1491.20
# Crystal Palace       1490.52
# RB Leipzig           1488.00
# Brighton             1486.55
# dtype: float64

# %%
name_local = "Arsenal"
name_away = "Aston Villa"

print(elo_dictionary[name_local])
print(elo_dictionary[name_away])

inference_vol1(name_local, name_away)
# Out:
# 1510.2340306274493
# 1514.3013217589264
# Arsenal vs Aston Villa
#
# Goles esperados Local: 1.81
# Goles esperados Visita: 1.43
#
# --- PRONÓSTICO PARA LA QUINIELA ---
# Diff -4.067291131477077
# Probabilidad Local (1): 43.9%
# Probabilidad Empate (X): 26.9%
# Probabilidad Visita (2): 29.2%
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# '2'

# %% [markdown]
# ### Evaluation Metrics

# %%
# import numpy as np

# # Listas para almacenar las diferencias encontradas
# lista_diferencias = []
# ejemplos_impresos = 0

# print("=== INICIANDO AUDITORÍA DE DIFERENCIAS DE PROBABILIDAD ===")

# # NOTA: Asegúrate de que 'df_test' o tu bucle use los nombres reales de tus columnas
# for index, row in df.iterrows():
#     name_local = row['home_team']  # Cambia por el nombre real de tu columna local
#     name_away = row['away_team']  # Cambia por el nombre real de tu columna visitante

#     if name_local in elo_dictionary and name_away in elo_dictionary:
#         elo_equipo_A = elo_dictionary[name_local]
#         elo_equipo_B = elo_dictionary[name_away]

#         # Predecir tasas Lambda
#         lambda_local = modelo_local.predict([[elo_equipo_A, elo_equipo_B]])[0]
#         lambda_visita = modelo_visita.predict([[elo_equipo_B, elo_equipo_A]])[0]

#         # Simular Poisson
#         prob_victoria_local = 0
#         prob_empate = 0
#         prob_victoria_visita = 0
#         max_goles = 5

#         for goles_L in range(max_goles + 1):
#             for goles_V in range(max_goles + 1):
#                 prob_marcador = poisson.pmf(goles_L, lambda_local) * poisson.pmf(goles_V, lambda_visita)
#                 if goles_L > goles_V:
#                     prob_victoria_local += prob_marcador
#                 elif goles_L == goles_V:
#                     prob_empate += prob_marcador
#                 else:
#                     prob_victoria_visita += prob_marcador

#         # Aplicar el ajuste original de empates de Mateo
#         elo_diff = elo_equipo_A - elo_equipo_B
#         if abs(elo_diff) < 200:
#             prob_empate += 0.04
#             espacio_restante = 1.0 - prob_empate
#             suma_victorias_original = prob_victoria_local + prob_victoria_visita
#             prob_victoria_local = (prob_victoria_local / suma_victorias_original) * espacio_restante
#             prob_victoria_visita = (prob_victoria_visita / suma_victorias_original) * espacio_restante

#         # Calcular la diferencia neta
#         dif_prob = prob_victoria_local - prob_victoria_visita
#         lista_diferencias.append(dif_prob)


# # Convertir a array de numpy para estadísticas globales
# lista_diferencias = np.array(lista_diferencias)

# print("\n=== REPORTE DE DISTRIBUCIÓN DE FRONTERAS ===")
# print(f"Partidos con diferencia <= 5%: {np.sum(abs(lista_diferencias) <= 0.05)}")
# print(f"Partidos con diferencia <= 10%: {np.sum(abs(lista_diferencias) <= 0.10)}")
# print(f"Partidos con diferencia <= 15%: {np.sum(abs(lista_diferencias) <= 0.15)}")
# print(f"Partidos con diferencia <= 20%: {np.sum(abs(lista_diferencias) <= 0.20)}")
# print(f"Diferencia mínima absoluta en todo el dataset: {abs(lista_diferencias).min()*100:.2f}%")
# print(f"Diferencia promedio en todo el dataset: {lista_diferencias.mean()*100:.2f}%")

# %%
warnings.filterwarnings("ignore")

y_true = []
y_pred = []
exitos = 0
omitidos = 0

# Evaluamos uno a uno los 41,641 partidos del DataFrame
for index, row in df.iterrows():
    local = row['home_team']
    visita = row['away_team']

    # 1. Validar que ambos equipos existan en las llaves del elo_dictionary
    if local not in elo_dictionary or visita not in elo_dictionary:
        omitidos += 1
        continue

    # 2. Determinar la etiqueta REAL del partido (Ground Truth)
    if row['home_goals'] > row['away_goals']:
        real = '1'  # Local
    elif row['home_goals'] == row['away_goals']:
        real = 'X'  # Empate
    else:
        real = '2'  # Visita

    try:
        # 3. Forzar a que la salida de texto no se trabe en consolas masivas (Silenciado dinámico)
        import sys, os
        actual_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')

        # 4. Llamamos a la función inference_vol1
        prediccion = inference_vol1(local, visita)

        # Restauramos canal de texto
        sys.stdout = actual_stdout

        if prediccion is not None:
            y_true.append(real)
            y_pred.append(prediccion)
            exitos += 1

            # Control de avance visual
            if exitos % 5000 == 0:
                print(f"-> {exitos} partidos analizados con éxito...")
    except Exception as e:
        sys.stdout = actual_stdout
        errores_conteo += 1
        continue

print("\n=== PROCESAMIENTO FINALIZADO ===")
print(f"Partidos evaluados con éxito: {exitos}")
print(f"Partidos omitidos por ausencia en diccionario: {omitidos}\n")
# Out:
# -> 5000 partidos analizados con éxito...
# -> 10000 partidos analizados con éxito...
# -> 15000 partidos analizados con éxito...
# -> 20000 partidos analizados con éxito...
# -> 25000 partidos analizados con éxito...
# -> 30000 partidos analizados con éxito...
# -> 35000 partidos analizados con éxito...
# -> 40000 partidos analizados con éxito...
#
# === PROCESAMIENTO FINALIZADO ===
# Partidos evaluados con éxito: 41654
# Partidos omitidos por ausencia en diccionario: 0

# %%
# CÁLCULO DE MÉTRICAS Y GRÁFICA DE LA MATRIZ DE CONFUSIÓN

if len(y_true) > 0:
    accuracy_test = accuracy_score(y_true, y_pred)
    matriz_conf = confusion_matrix(y_true, y_pred, labels=['1', 'X', '2'])
    reporte = classification_report(
        y_true, y_pred,
        labels=['1', 'X', '2'],
        target_names=['Local (1)', 'Empate (X)', 'Visita (2)'],
        zero_division=0
    )

    print(f"Accuracy Global en Test: {accuracy_test * 100:.2f}%\n")
    print("=== REPORTE DE CLASIFICACIÓN ===")
    print(reporte)

    # Dibujar la matriz de confusión gráfica
    plt.figure(figsize=(7, 5))
    sns.heatmap(matriz_conf, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Pred Local (1)', 'Pred Empate (X)', 'Pred Visita (2)'],
                yticklabels=['Real Local (1)', 'Real Empate (X)', 'Real Visita (2)'])
    plt.title("Matriz de Confusión - Modelo Baseline (Poisson + ELO)")
    plt.ylabel("Etiqueta Real")
    plt.xlabel("Predicción del Modelo")
    plt.show()
else:
    print("Asegúrate de correr las celdas donde entrenas 'modelo_local' y 'modelo_visita'.")
# Out:
# Accuracy Global en Test: 46.31%
#
# === REPORTE DE CLASIFICACIÓN ===
#               precision    recall  f1-score   support
#
#    Local (1)       0.49      0.73      0.59     18841
#   Empate (X)       0.23      0.02      0.03      8346
#   Visita (2)       0.41      0.37      0.39     14467
#
#     accuracy                           0.46     41654
#    macro avg       0.38      0.37      0.34     41654
# weighted avg       0.41      0.46      0.41     41654

# %% [markdown]
# ### Modelos Alternativos

# %%
warnings.filterwarnings("ignore")

# Filtramos de golpe los partidos que no están en el diccionario de ELO
partidos_validos = []

for index, row in df.iterrows():
    local = row['home_team']
    visita = row['away_team']
    if local in elo_dictionary and visita in elo_dictionary:
        # Determinamos la etiqueta REAL (Ground Truth)
        if row['home_goals'] > row['away_goals']:
            real = '1'
        elif row['home_goals'] == row['away_goals']:
            real = 'X'
        else:
            real = '2'

        partidos_validos.append({
            'home_elo': elo_dictionary[local],
            'away_elo': elo_dictionary[visita],
            'elo_diff': elo_dictionary[local] - elo_dictionary[visita],
            'target': real
        })

# %%
# Creamos el DataFrame limpio optimizado
df_ml = pd.DataFrame(partidos_validos)
df_ml.head()
# Out:
#    home_elo  away_elo      elo_diff target
# 0    1500.0    1500.0  4.547474e-13      2
# 1    1500.0    1500.0  0.000000e+00      1
# 2    1500.0    1500.0 -4.547474e-13      1
# 3    1500.0    1500.0  0.000000e+00      X
# 4    1500.0    1500.0 -4.547474e-13      2

# %%
# Limpiamos el residuo numérico flotante redondeando a 2 decimales
df_ml['elo_diff'] = df_ml['elo_diff'].round(2)
df_ml.head()
# Out:
#    home_elo  away_elo  elo_diff target
# 0    1500.0    1500.0       0.0      2
# 1    1500.0    1500.0       0.0      1
# 2    1500.0    1500.0      -0.0      1
# 3    1500.0    1500.0       0.0      X
# 4    1500.0    1500.0      -0.0      2

# %%
# definimos las características
features = ['home_elo', 'away_elo', 'elo_diff']

X = df_ml[features]
y = df_ml['target']

# %%
# Volvemos a partir y escalar
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
print(f"Partidos totales para ML: {df_ml.shape[0]}")
print(f"Omitidos originalmente: {len(df) - df_ml.shape[0]}\n")
# Out:
# Partidos totales para ML: 41654
# Omitidos originalmente: 0

# %%
#Definir los modelos a usar
modelos = {
    "Regresión Logística": LogisticRegression(multi_class='multinomial', max_iter=1000, random_state=42),
    "Árbol de Decisión": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "AdaBoost": AdaBoostClassifier(n_estimators=50, random_state=42),
    "Máquina de Vector de Soporte (SVC)": SVC(probability=True, random_state=42),
    "K-Nearest Neighbors (KNN)": KNeighborsClassifier(),
    "Naive Bayes Gaussiano": GaussianNB(),
    "Perceptrón Multicapa (MLP)": MLPClassifier(max_iter=300, random_state=42)
}

# %%
reporte_resultados = []

print("=== ENTRENANDO LOS MODELOS ===")
print(f"Accuracy en modelo baseline: {accuracy_test * 100:.2f}%\n")
for nombre, modelo in modelos.items():
    # Entrenamos con el 80% de los datos
    modelo.fit(X_train_scaled, y_train)

    # Predecimos el 20% restante (Vectorizado)
    preds = modelo.predict(X_test_scaled)

    # Calculamos métricas de calidad
    acc = accuracy_score(y_test, preds)
    acc_pcg = acc * 100
    f1_macro = f1_score(y_test, preds, average='macro')

    reporte_resultados.append({
        "Algoritmo": nombre,
        "Accuracy Global": acc_pcg,
        "F1-Score (Macro)": f1_macro
    })
    print(f"-> {nombre} evaluado exitosamente...")

# Presentamos la tabla comparativa
df_comparativo = pd.DataFrame(reporte_resultados).sort_values(by="Accuracy Global", ascending=False)
print("\n=== TABLA COMPARATIVA DE RENDIMIENTO ===")
print(df_comparativo.to_string(index=False))
# Out:
# === ENTRENANDO LOS MODELOS ===
# Accuracy en modelo baseline: 46.31%
#
# -> Regresión Logística evaluado exitosamente...
# -> Árbol de Decisión evaluado exitosamente...
# -> Random Forest evaluado exitosamente...
# -> AdaBoost evaluado exitosamente...
# -> Máquina de Vector de Soporte (SVC) evaluado exitosamente...
# -> K-Nearest Neighbors (KNN) evaluado exitosamente...
# -> Naive Bayes Gaussiano evaluado exitosamente...
# -> Perceptrón Multicapa (MLP) evaluado exitosamente...
#
# === TABLA COMPARATIVA DE RENDIMIENTO ===
#                          Algoritmo  Accuracy Global  F1-Score (Macro)
#                           AdaBoost        45.792822          0.233254
#         Perceptrón Multicapa (MLP)        45.588765          0.227920
# Máquina de Vector de Soporte (SVC)        45.564758          0.234268
#                  Árbol de Decisión        45.408714          0.279383
#              Naive Bayes Gaussiano        45.348698          0.234573
#                      Random Forest        45.240667          0.281087
#                Regresión Logística        45.228664          0.207620
#          K-Nearest Neighbors (KNN)        39.274997          0.341210

# %%
# Selección de los Dos Mejores Modelos Individuales

top_3_acc = df_comparativo['Algoritmo'].head(3).tolist()
print(f"\nLos dos mejores modelos seleccionados para ajuste fino son: {top_3_acc} comparado con que el modelo baseline dio un accuracy de {accuracy_test * 100:.2f}%\n")
# Out:
# Los dos mejores modelos seleccionados para ajuste fino son: ['AdaBoost', 'Perceptrón Multicapa (MLP)', 'Máquina de Vector de Soporte (SVC)'] comparado con que el modelo baseline dio un accuracy de 46.31%

# %%
print("\n[Optimización] Ajustando SVC...")
# Acotamos la malla al espacio más probable para datos estructurados de ELO
param_grid_svc = {
    'C': [0.1, 1.0, 5.0],
    'kernel': ['rbf'] #
}
grid_svc = GridSearchCV(
    estimator=SVC(probability=False, random_state=42),
    param_grid=param_grid_svc,
    cv=3,
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)
grid_svc.fit(X_train_scaled, y_train)
best_svc = grid_svc.best_estimator_
print(f"Mejores parámetros SVC: {grid_svc.best_params_}")
print(f"Nuevo Accuracy en Test: {accuracy_score(y_test, best_svc.predict(X_test_scaled))*100:.2f}%")
# Out:
# [Optimización] Ajustando SVC...
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# Mejores parámetros SVC: {'C': 1.0, 'kernel': 'rbf'}
# Nuevo Accuracy en Test: 45.56%

# %%
print("Configurando el modelo final SVC entrenado...")
mejores_params = grid_svc.best_params_
best_model_svc = SVC(C=mejores_params['C'], kernel=mejores_params['kernel'], probability=True, random_state=42)
best_model_svc.fit(X_train_scaled, y_train)

# Evaluamos
preds_svc = best_model_svc.predict(X_test_scaled)
print(f"Nuevo Accuracy de SVC en Test: {accuracy_score(y_test, preds_svc)*100:.2f}%")

print("\n=== REPORTE DE CLASIFICACIÓN (SVC OPTIMIZADO) ===")
print(classification_report(y_test, preds_svc))
# Out:
# Configurando el modelo final SVC entrenado...
# Nuevo Accuracy de SVC en Test: 45.56%
#
# === REPORTE DE CLASIFICACIÓN (SVC OPTIMIZADO) ===
#               precision    recall  f1-score   support
#
#            1       0.46      0.97      0.62      3768
#            2       0.48      0.04      0.08      2894
#            X       0.33      0.00      0.01      1669
#
#     accuracy                           0.46      8331
#    macro avg       0.42      0.34      0.23      8331
# weighted avg       0.44      0.46      0.31      8331

# %%
matriz_conf_svc = confusion_matrix(y_test, preds_svc, labels=['1', 'X', '2'])
# Dibujar la matriz de confusión gráfica
plt.figure(figsize=(7, 5))
sns.heatmap(matriz_conf_svc, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Pred Local (1)', 'Pred Empate (X)', 'Pred Visita (2)'],
            yticklabels=['Real Local (1)', 'Real Empate (X)', 'Real Visita (2)'])
plt.title("Matriz de Confusión - Modelo SVC")
plt.ylabel("Etiqueta Real")
plt.xlabel("Predicción del Modelo")
plt.show()

# %%
print("\n[Optimización] Ajustando MLP...")
param_grid_mlp = {
    'hidden_layer_sizes': [(50,), (50, 25)],
    'activation': ['relu', 'tanh'],
    'alpha': [0.0001, 0.005],
    'solver': ['adam']
}
grid_mlp = GridSearchCV(
    estimator=MLPClassifier(max_iter=400, random_state=42),
    param_grid=param_grid_mlp,
    cv=3,
    scoring='accuracy',
    n_jobs=-1,
    verbose=2
)
grid_mlp.fit(X_train_scaled, y_train)
best_mlp = grid_mlp.best_estimator_
print(f"Mejores parámetros MLP: {grid_mlp.best_params_}")
print(f"Nuevo Accuracy en Test: {accuracy_score(y_test, best_mlp.predict(X_test_scaled))*100:.2f}%")
# Out:
# [Optimización] Ajustando MLP...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# Mejores parámetros MLP: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (50, 25), 'solver': 'adam'}
# Nuevo Accuracy en Test: 45.54%

# %%
print("Configurando el modelo final MLP entrenado...")
mejores_params = grid_mlp.best_params_
best_model_mlp = MLPClassifier(
    activation='relu',
    alpha=0.005,
    hidden_layer_sizes=(50, 25),
    solver='adam',
    max_iter=500,       # Le dejamos buen margen para asegurar convergencia
    random_state=42     # Mismo random_state para mantener la reproducibilidad
)
best_model_mlp.fit(X_train_scaled, y_train)

# Evaluamos
preds_mlp = best_model_mlp.predict(X_test_scaled)
print(f"Nuevo Accuracy de MLP en Test: {accuracy_score(y_test, preds_mlp)*100:.2f}%")

print("\n=== REPORTE DE CLASIFICACIÓN (MLP OPTIMIZADO) ===")
print(classification_report(y_test, preds_mlp))
# Out:
# Configurando el modelo final MLP entrenado...
# Nuevo Accuracy de MLP en Test: 45.54%
#
# === REPORTE DE CLASIFICACIÓN (MLP OPTIMIZADO) ===
#               precision    recall  f1-score   support
#
#            1       0.46      0.97      0.62      3768
#            2       0.45      0.04      0.08      2894
#            X       0.00      0.00      0.00      1669
#
#     accuracy                           0.46      8331
#    macro avg       0.30      0.34      0.23      8331
# weighted avg       0.36      0.46      0.31      8331

# %%
matriz_conf_mlp = confusion_matrix(y_test, preds_mlp, labels=['1', 'X', '2'])
# Dibujar la matriz de confusión gráfica
plt.figure(figsize=(7, 5))
sns.heatmap(matriz_conf_mlp, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Pred Local (1)', 'Pred Empate (X)', 'Pred Visita (2)'],
            yticklabels=['Real Local (1)', 'Real Empate (X)', 'Real Visita (2)'])
plt.title("Matriz de Confusión - Modelo MLP")
plt.ylabel("Etiqueta Real")
plt.xlabel("Predicción del Modelo")
plt.show()

# %%
print("\n[Optimización] Ajustando ADABOOST...")
param_grid_ada = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1, 1.0],
    'estimator': [DecisionTreeClassifier(max_depth=1), DecisionTreeClassifier(max_depth=2)]
}
grid_ada = GridSearchCV(
    estimator=AdaBoostClassifier(random_state=42),
    param_grid=param_grid_ada,
    cv=3,
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)
grid_ada.fit(X_train_scaled, y_train)
best_ada = grid_ada.best_estimator_
print(f"Mejores parámetros Adaboost: {grid_ada.best_params_}")
print(f"Nuevo Accuracy en Test: {accuracy_score(y_test, best_ada.predict(X_test_scaled))*100:.2f}%")
# Out:
# [Optimización] Ajustando ADABOOST...
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# Mejores parámetros Adaboost: {'estimator': DecisionTreeClassifier(max_depth=2), 'learning_rate': 1.0, 'n_estimators': 150}
# Nuevo Accuracy en Test: 45.90%

# %%
print("Configurando el modelo final Adaboost entrenado...")
mejores_params = grid_ada.best_params_
best_model_ada = grid_ada.best_estimator_
best_model_ada.fit(X_train_scaled, y_train)

# Evaluamos
preds_ada = best_model_ada.predict(X_test_scaled)
print(f"Nuevo Accuracy de Adaboost en Test: {accuracy_score(y_test, preds_ada)*100:.2f}%")

print("\n=== REPORTE DE CLASIFICACIÓN (Adaboost OPTIMIZADO) ===")
print(classification_report(y_test, preds_ada))
# Out:
# Configurando el modelo final Adaboost entrenado...
# Nuevo Accuracy de Adaboost en Test: 45.90%
#
# === REPORTE DE CLASIFICACIÓN (Adaboost OPTIMIZADO) ===
#               precision    recall  f1-score   support
#
#            1       0.46      0.94      0.62      3768
#            2       0.45      0.10      0.17      2894
#            X       0.00      0.00      0.00      1669
#
#     accuracy                           0.46      8331
#    macro avg       0.30      0.35      0.26      8331
# weighted avg       0.36      0.46      0.34      8331

# %%
matriz_conf_ada = confusion_matrix(y_test, preds_ada, labels=['1', 'X', '2'])
# Dibujar la matriz de confusión gráfica
plt.figure(figsize=(7, 5))
sns.heatmap(matriz_conf_ada, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Pred Local (1)', 'Pred Empate (X)', 'Pred Visita (2)'],
            yticklabels=['Real Local (1)', 'Real Empate (X)', 'Real Visita (2)'])
plt.title("Matriz de Confusión - Modelo Adaboost")
plt.ylabel("Etiqueta Real")
plt.xlabel("Predicción del Modelo")
plt.show()

# %%
print("\n[Optimización] Ajustando KNN...")
param_grid_knn = {
    'n_neighbors': [5, 9, 15, 21],          # Número de vecinos
    'weights': ['uniform', 'distance'],      # Peso por cercanía
    'metric': ['euclidean', 'manhattan']     # Tipo de distancia
}
grid_knn = GridSearchCV(KNeighborsClassifier(), param_grid_knn, cv=3, scoring='accuracy', n_jobs=-1)
grid_knn.fit(X_train_scaled, y_train)
best_knn = grid_knn.best_estimator_
print(f"Mejores parámetros KNN: {grid_knn.best_params_}")
print(f"Nuevo Accuracy en Test: {accuracy_score(y_test, best_knn.predict(X_test_scaled))*100:.2f}%")
# Out:
# [Optimización] Ajustando KNN...
# Mejores parámetros KNN: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# Nuevo Accuracy en Test: 39.25%

# %%
print("Configurando el modelo final KNN entrenado...")
mejores_params = grid_knn.best_params_
best_model_knn = grid_knn.best_estimator_
best_model_knn.fit(X_train_scaled, y_train)

# Evaluamos
preds_knn = best_model_knn.predict(X_test_scaled)
print(f"Nuevo Accuracy de KNN en Test: {accuracy_score(y_test, preds_knn)*100:.2f}%")

print("\n=== REPORTE DE CLASIFICACIÓN (KNN OPTIMIZADO) ===")
print(classification_report(y_test, preds_knn))
# Out:
# Configurando el modelo final KNN entrenado...
# Nuevo Accuracy de KNN en Test: 39.25%
#
# === REPORTE DE CLASIFICACIÓN (KNN OPTIMIZADO) ===
#               precision    recall  f1-score   support
#
#            1       0.47      0.59      0.52      3768
#            2       0.37      0.25      0.30      2894
#            X       0.20      0.21      0.20      1669
#
#     accuracy                           0.39      8331
#    macro avg       0.35      0.35      0.34      8331
# weighted avg       0.38      0.39      0.38      8331

# %%
matriz_conf_knn = confusion_matrix(y_test, preds_knn, labels=['1', 'X', '2'])
# Dibujar la matriz de confusión gráfica
plt.figure(figsize=(7, 5))
sns.heatmap(matriz_conf_knn, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Pred Local (1)', 'Pred Empate (X)', 'Pred Visita (2)'],
            yticklabels=['Real Local (1)', 'Real Empate (X)', 'Real Visita (2)'])
plt.title("Matriz de Confusión - Modelo KNN")
plt.ylabel("Etiqueta Real")
plt.xlabel("Predicción del Modelo")
plt.show()

# %%
print("\n[Optimización] Ajustando Naive Bayes...")
param_grid_nb = {
    'var_smoothing': [1e-09, 1e-08, 1e-07]   # Suavizado de varianza para estabilidad
}
grid_nb = GridSearchCV(GaussianNB(), param_grid_nb, cv=3, scoring='accuracy', n_jobs=-1)
grid_nb.fit(X_train_scaled, y_train)
best_nb = grid_nb.best_estimator_
print(f"Mejores parámetros NB: {grid_nb.best_params_}")
print(f"Nuevo Accuracy en Test: {accuracy_score(y_test, best_nb.predict(X_test_scaled))*100:.2f}%")
# Out:
# [Optimización] Ajustando Naive Bayes...
# Mejores parámetros NB: {'var_smoothing': 1e-09}
# Nuevo Accuracy en Test: 45.35%

# %%
print("Configurando el modelo final NB entrenado...")
mejores_params = grid_nb.best_params_
best_model_nb = grid_nb.best_estimator_
best_model_nb.fit(X_train_scaled, y_train)

# Evaluamos
preds_nb = best_model_nb.predict(X_test_scaled)
print(f"Nuevo Accuracy de NB en Test: {accuracy_score(y_test, preds_nb)*100:.2f}%")

print("\n=== REPORTE DE CLASIFICACIÓN (NB OPTIMIZADO) ===")
print(classification_report(y_test, preds_nb))
# Out:
# Configurando el modelo final NB entrenado...
# Nuevo Accuracy de NB en Test: 45.35%
#
# === REPORTE DE CLASIFICACIÓN (NB OPTIMIZADO) ===
#               precision    recall  f1-score   support
#
#            1       0.45      0.97      0.62      3768
#            2       0.44      0.04      0.07      2894
#            X       0.25      0.01      0.01      1669
#
#     accuracy                           0.45      8331
#    macro avg       0.38      0.34      0.23      8331
# weighted avg       0.41      0.45      0.31      8331

# %%
matriz_conf_nb = confusion_matrix(y_test, preds_nb, labels=['1', 'X', '2'])
# Dibujar la matriz de confusión gráfica
plt.figure(figsize=(7, 5))
sns.heatmap(matriz_conf_nb, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Pred Local (1)', 'Pred Empate (X)', 'Pred Visita (2)'],
            yticklabels=['Real Local (1)', 'Real Empate (X)', 'Real Visita (2)'])
plt.title("Matriz de Confusión - Modelo NB")
plt.ylabel("Etiqueta Real")
plt.xlabel("Predicción del Modelo")
plt.show()

# %%
print("\n[Optimización] Ajustando Regresión Logística...")
param_grid_lr = {
    'C': [0.01, 0.1, 1.0, 10.0],             # Inverso de la fuerza de regularización
    'solver': ['lbfgs', 'saga'],             # Algoritmos de optimización
    'multi_class': ['multinomial']
}
grid_lr = GridSearchCV(LogisticRegression(max_iter=1000, random_state=42), param_grid_lr, cv=3, scoring='accuracy', n_jobs=-1)
grid_lr.fit(X_train_scaled, y_train)
best_lr = grid_lr.best_estimator_
print(f"Mejores parámetros LR: {grid_lr.best_params_}")
print(f"Nuevo Accuracy en Test: {accuracy_score(y_test, best_lr.predict(X_test_scaled))*100:.2f}%")
# Out:
# [Optimización] Ajustando Regresión Logística...
# Mejores parámetros LR: {'C': 0.01, 'multi_class': 'multinomial', 'solver': 'lbfgs'}
# Nuevo Accuracy en Test: 45.23%

# %%
print("Configurando el modelo final LR entrenado...")
mejores_params = grid_lr.best_params_
best_model_lr = grid_lr.best_estimator_
best_model_lr.fit(X_train_scaled, y_train)

# Evaluamos
preds_lr = best_model_lr.predict(X_test_scaled)
print(f"Nuevo Accuracy de LR en Test: {accuracy_score(y_test, preds_lr)*100:.2f}%")

print("\n=== REPORTE DE CLASIFICACIÓN (LR OPTIMIZADO) ===")
print(classification_report(y_test, preds_lr))
# Out:
# Configurando el modelo final LR entrenado...
# Nuevo Accuracy de LR en Test: 45.23%
#
# === REPORTE DE CLASIFICACIÓN (LR OPTIMIZADO) ===
#               precision    recall  f1-score   support
#
#            1       0.45      1.00      0.62      3768
#            2       0.00      0.00      0.00      2894
#            X       0.00      0.00      0.00      1669
#
#     accuracy                           0.45      8331
#    macro avg       0.15      0.33      0.21      8331
# weighted avg       0.20      0.45      0.28      8331

# %%
matriz_conf_lr = confusion_matrix(y_test, preds_lr, labels=['1', 'X', '2'])
# Dibujar la matriz de confusión gráfica
plt.figure(figsize=(7, 5))
sns.heatmap(matriz_conf_lr, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Pred Local (1)', 'Pred Empate (X)', 'Pred Visita (2)'],
            yticklabels=['Real Local (1)', 'Real Empate (X)', 'Real Visita (2)'])
plt.title("Matriz de Confusión - Modelo LR")
plt.ylabel("Etiqueta Real")
plt.xlabel("Predicción del Modelo")
plt.show()

# %%
print("\n[Optimización] Ajustando Árbol de Decisión...")
param_grid_dt = {
    'max_depth': [4, 6, 8, 12],              # Control del crecimiento para evitar sobreajuste
    'min_samples_split': [10, 20, 50],       # Mínimo de muestras para dividir nodo
    'criterion': ['gini', 'entropy']
}
grid_dt = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid_dt, cv=3, scoring='accuracy', n_jobs=-1)
grid_dt.fit(X_train_scaled, y_train)
best_dt = grid_dt.best_estimator_
print(f"Mejores parámetros DT: {grid_dt.best_params_}")
print(f"Nuevo Accuracy en Test: {accuracy_score(y_test, best_dt.predict(X_test_scaled))*100:.2f}%")
# Out:
# [Optimización] Ajustando Árbol de Decisión...
# Mejores parámetros DT: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 10}
# Nuevo Accuracy en Test: 45.86%

# %%
print("Configurando el modelo final DT entrenado...")
mejores_params = grid_dt.best_params_
best_model_dt = grid_dt.best_estimator_
best_model_dt.fit(X_train_scaled, y_train)

# Evaluamos
preds_dt = best_model_dt.predict(X_test_scaled)
print(f"Nuevo Accuracy de DT en Test: {accuracy_score(y_test, preds_dt)*100:.2f}%")

print("\n=== REPORTE DE CLASIFICACIÓN (DT OPTIMIZADO) ===")
print(classification_report(y_test, preds_dt))
# Out:
# Configurando el modelo final DT entrenado...
# Nuevo Accuracy de DT en Test: 45.86%
#
# === REPORTE DE CLASIFICACIÓN (DT OPTIMIZADO) ===
#               precision    recall  f1-score   support
#
#            1       0.46      0.93      0.62      3768
#            2       0.44      0.11      0.18      2894
#            X       0.35      0.00      0.01      1669
#
#     accuracy                           0.46      8331
#    macro avg       0.42      0.35      0.27      8331
# weighted avg       0.43      0.46      0.34      8331

# %%
matriz_conf_dt = confusion_matrix(y_test, preds_dt, labels=['1', 'X', '2'])
# Dibujar la matriz de confusión gráfica
plt.figure(figsize=(7, 5))
sns.heatmap(matriz_conf_dt, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Pred Local (1)', 'Pred Empate (X)', 'Pred Visita (2)'],
            yticklabels=['Real Local (1)', 'Real Empate (X)', 'Real Visita (2)'])
plt.title("Matriz de Confusión - Modelo DT")
plt.ylabel("Etiqueta Real")
plt.xlabel("Predicción del Modelo")
plt.show()

# %%
print("\n[Optimización] Ajustando Random Forest...")
param_grid_rf = {
    'n_estimators': [100, 200],              # Cantidad de árboles en el ensamble
    'max_depth': [6, 8, 10],                 # Profundidad máxima
    'criterion': ['gini', 'entropy']
}
grid_rf = GridSearchCV(RandomForestClassifier(random_state=42, n_jobs=-1), param_grid_rf, cv=3, scoring='accuracy', n_jobs=-1)
grid_rf.fit(X_train_scaled, y_train)
best_rf = grid_rf.best_estimator_
print(f"Mejores parámetros RF: {grid_rf.best_params_}")
print(f"Nuevo Accuracy en Test: {accuracy_score(y_test, best_rf.predict(X_test_scaled))*100:.2f}%")
# Out:
# [Optimización] Ajustando Random Forest...
# Mejores parámetros RF: {'criterion': 'gini', 'max_depth': 8, 'n_estimators': 200}
# Nuevo Accuracy en Test: 46.24%

# %%
print("Configurando el modelo final RF entrenado...")
mejores_params = grid_rf.best_params_
best_model_rf = grid_rf.best_estimator_
best_model_rf.fit(X_train_scaled, y_train)

# Evaluamos
preds_rf = best_model_rf.predict(X_test_scaled)
print(f"Nuevo Accuracy de RF en Test: {accuracy_score(y_test, preds_rf)*100:.2f}%")

print("\n=== REPORTE DE CLASIFICACIÓN (RF OPTIMIZADO) ===")
print(classification_report(y_test, preds_rf))
# Out:
# Configurando el modelo final RF entrenado...
# Nuevo Accuracy de RF en Test: 46.24%
#
# === REPORTE DE CLASIFICACIÓN (RF OPTIMIZADO) ===
#               precision    recall  f1-score   support
#
#            1       0.46      0.95      0.62      3768
#            2       0.48      0.10      0.16      2894
#            X       0.41      0.01      0.01      1669
#
#     accuracy                           0.46      8331
#    macro avg       0.45      0.35      0.26      8331
# weighted avg       0.46      0.46      0.34      8331

# %%
matriz_conf_rf = confusion_matrix(y_test, preds_rf, labels=['1', 'X', '2'])
# Dibujar la matriz de confusión gráfica
plt.figure(figsize=(7, 5))
sns.heatmap(matriz_conf_rf, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Pred Local (1)', 'Pred Empate (X)', 'Pred Visita (2)'],
            yticklabels=['Real Local (1)', 'Real Empate (X)', 'Real Visita (2)'])
plt.title("Matriz de Confusión - Modelo RF")
plt.ylabel("Etiqueta Real")
plt.xlabel("Predicción del Modelo")
plt.show()

# %%
cr_baseline = reporte
cr_svc = classification_report(y_test, preds_svc)
cr_mlp = classification_report(y_test, preds_mlp)
cr_ada = classification_report(y_test, preds_ada)
cr_knn = classification_report(y_test, preds_knn)
cr_nb  = classification_report(y_test, preds_nb)
cr_lr  = classification_report(y_test, preds_lr)
cr_dt  = classification_report(y_test, preds_dt)
cr_rf  = classification_report(y_test, preds_rf)

# %%
reportes = {
    "Modelo Baseline (ELO + Poisson)": cr_baseline,
    "Máquina de Vector de Soporte (SVC) Optimizado": cr_svc,
    "Perceptrón Multicapa (MLP) Optimizado": cr_mlp,
    "AdaBoost Optimizado": cr_ada,
    "K-Nearest Neighbors (KNN) Optimizado": cr_knn,
    "Naive Bayes Gaussiano Optimizado": cr_nb,
    "Regresión Logística Optimizada": cr_lr,
    "Árbol de Decisión Optimizado": cr_dt,
    "Random Forest Optimizado": cr_rf
}

# %%
for nombre_modelo, reporte_texto in reportes.items():
    print(f"===============================================================")
    print(f" ALGORITMO: {nombre_modelo}")
    print(f"===============================================================")
    print(reporte_texto)
    print("\n")
# Out:
# ===============================================================
#  ALGORITMO: Modelo Baseline (ELO + Poisson)
# ===============================================================
#               precision    recall  f1-score   support
#
#    Local (1)       0.49      0.73      0.59     18841
#   Empate (X)       0.23      0.02      0.03      8346
#   Visita (2)       0.41      0.37      0.39     14467
#
#     accuracy                           0.46     41654
#    macro avg       0.38      0.37      0.34     41654
# weighted avg       0.41      0.46      0.41     41654
#
#
#
# ===============================================================
#  ALGORITMO: Máquina de Vector de Soporte (SVC) Optimizado
# ===============================================================
#               precision    recall  f1-score   support
#
#            1       0.46      0.97      0.62      3768
#            2       0.48      0.04      0.08      2894
#            X       0.33      0.00      0.01      1669
#
#     accuracy                           0.46      8331
#    macro avg       0.42      0.34      0.23      8331
# weighted avg       0.44      0.46      0.31      8331
#
#
#
# ===============================================================
#  ALGORITMO: Perceptrón Multicapa (MLP) Optimizado
# ===============================================================
#               precision    recall  f1-score   support
#
#            1       0.46      0.97      0.62      3768
#            2       0.45      0.04      0.08      2894
#            X       0.00      0.00      0.00      1669
#
#     accuracy                           0.46      8331
#    macro avg       0.30      0.34      0.23      8331
# weighted avg       0.36      0.46      0.31      8331
#
#
#
# ===============================================================
#  ALGORITMO: AdaBoost Optimizado
# ===============================================================
#               precision    recall  f1-score   support
#
#            1       0.46      0.94      0.62      3768
#            2       0.45      0.10      0.17      2894
#            X       0.00      0.00      0.00      1669
#
#     accuracy                           0.46      8331
#    macro avg       0.30      0.35      0.26      8331
# weighted avg       0.36      0.46      0.34      8331
#
#
#
# ===============================================================
#  ALGORITMO: K-Nearest Neighbors (KNN) Optimizado
# ===============================================================
#               precision    recall  f1-score   support
#
#            1       0.47      0.59      0.52      3768
#            2       0.37      0.25      0.30      2894
#            X       0.20      0.21      0.20      1669
#
#     accuracy                           0.39      8331
#    macro avg       0.35      0.35      0.34      8331
# weighted avg       0.38      0.39      0.38      8331
#
#
#
# ===============================================================
#  ALGORITMO: Naive Bayes Gaussiano Optimizado
# ===============================================================
#               precision    recall  f1-score   support
#
#            1       0.45      0.97      0.62      3768
#            2       0.44      0.04      0.07      2894
#            X       0.25      0.01      0.01      1669
#
#     accuracy                           0.45      8331
#    macro avg       0.38      0.34      0.23      8331
# weighted avg       0.41      0.45      0.31      8331
#
#
#
# ===============================================================
#  ALGORITMO: Regresión Logística Optimizada
# ===============================================================
#               precision    recall  f1-score   support
#
#            1       0.45      1.00      0.62      3768
#            2       0.00      0.00      0.00      2894
#            X       0.00      0.00      0.00      1669
#
#     accuracy                           0.45      8331
#    macro avg       0.15      0.33      0.21      8331
# weighted avg       0.20      0.45      0.28      8331
#
#
#
# ===============================================================
#  ALGORITMO: Árbol de Decisión Optimizado
# ===============================================================
#               precision    recall  f1-score   support
#
#            1       0.46      0.95      0.62      3768
#            2       0.48      0.10      0.16      2894
#            X       0.41      0.01      0.01      1669
#
#     accuracy                           0.46      8331
#    macro avg       0.45      0.35      0.26      8331
# weighted avg       0.46      0.46      0.34      8331
#
#
#
# ===============================================================
#  ALGORITMO: Random Forest Optimizado
# ===============================================================
#               precision    recall  f1-score   support
#
#            1       0.46      0.95      0.62      3768
#            2       0.48      0.10      0.16      2894
#            X       0.41      0.01      0.01      1669
#
#     accuracy                           0.46      8331
#    macro avg       0.45      0.35      0.26      8331
# weighted avg       0.46      0.46      0.34      8331
